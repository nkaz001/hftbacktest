# %% [markdown]
# # Working with Market Depth and Trades

# %% [markdown]
# ## Display 3-depth

# %%
from numba import njit

@njit
def print_3depth(hbt):
    while hbt.run:
        if not hbt.elapse(60 * 1e6):
            return False
        
        # a key of bid_depth or ask_depth is price in tick format.
        # (integer) price_tick = price / tick_size
        print('current_timestamp:', hbt.current_timestamp)
        i = 0
        for tick_price in range(hbt.best_ask_tick, hbt.high_ask_tick + 1):
            if tick_price in hbt.ask_depth:
                print(
                    'ask: ',
                    hbt.ask_depth[tick_price],
                    '@',
                    round(tick_price * hbt.tick_size, 3)
                )
                i += 1
                if i == 3:
                    break
        i = 0
        for tick_price in range(hbt.best_bid_tick, hbt.low_bid_tick - 1, -1):
            if tick_price in hbt.bid_depth:
                print(
                    'bid: ',
                    hbt.bid_depth[tick_price],
                    '@',
                    round(tick_price * hbt.tick_size, 3)
                )
                i += 1
                if i == 3:
                    break
    return True

# %%
import numpy as np

btcusdt_20230405 = np.load('btcusdt_20230405.npz')['data']
btcusdt_20230404_eod = np.load('btcusdt_20230404_eod.npz')['data']

# %%
from hftbacktest import HftBacktest, FeedLatency, Linear

hbt = HftBacktest(
    btcusdt_20230405,
    tick_size=0.1,
    lot_size=0.001,
    maker_fee=0.0002,
    taker_fee=0.0007,
    order_latency=FeedLatency(),
    asset_type=Linear,
    snapshot=btcusdt_20230404_eod
)

print_3depth(hbt)
# Out:
# current_timestamp: 1680652860032116
# ask:  9.228 @ 28150.8
# ask:  0.387 @ 28150.9
# ask:  3.996 @ 28151.0
# bid:  3.135 @ 28150.7
# bid:  0.002 @ 28150.6
# bid:  0.813 @ 28150.5
# current_timestamp: 1680652920032116
# ask:  1.224 @ 28144.2
# ask:  0.223 @ 28144.3
# ask:  0.001 @ 28144.5
# bid:  10.529 @ 28144.1
# bid:  0.168 @ 28144.0
# bid:  0.29 @ 28143.9
# current_timestamp: 1680652980032116
# ask:  3.397 @ 28150.0
# ask:  1.282 @ 28150.1
# ask:  0.003 @ 28150.4
# bid:  7.951 @ 28149.9
# bid:  0.02 @ 28149.8
# bid:  0.02 @ 28149.7
# current_timestamp: 1680653040032116
# ask:  3.905 @ 28145.8
# ask:  1.695 @ 28145.9
# ask:  0.003 @ 28146.0
# bid:  5.793 @ 28145.7
# bid:  0.059 @ 28145.6
# bid:  0.044 @ 28145.5
# current_timestamp: 1680653100032116
# ask:  6.8 @ 28140.6
# ask:  0.001 @ 28140.7
# ask:  0.004 @ 28141.1
# bid:  2.416 @ 28140.5
# bid:  0.004 @ 28140.4
# bid:  0.012 @ 28140.3
# current_timestamp: 1680653160032116
# ask:  3.666 @ 28143.9
# ask:  1.422 @ 28144.0
# ask:  1.455 @ 28144.1
# bid:  3.189 @ 28143.8
# bid:  5.136 @ 28143.7
# bid:  0.012 @ 28143.5
# False

# %% [markdown]
# ## Order Book Imbalance

# %%
@njit
def orderbookimbalance(hbt, out):
    while hbt.run:
        if not hbt.elapse(10 * 1e6):
            return False
        
        mid_price = (hbt.best_bid + hbt.best_ask) / 2.0
        
        sum_ask_qty_50bp = 0.0
        sum_ask_qty = 0.0
        for tick_price in range(hbt.best_ask_tick, hbt.high_ask_tick + 1):
            if tick_price in hbt.ask_depth:
                ask_price = tick_price * hbt.tick_size
                depth_from_mid = (ask_price - mid_price) / mid_price
                if depth_from_mid > 0.01:
                    break
                sum_ask_qty += hbt.ask_depth[tick_price]
                
                if depth_from_mid <= 0.005:
                    sum_ask_qty_50bp = sum_ask_qty
                
                
        sum_bid_qty_50bp = 0.0
        sum_bid_qty = 0.0
        for tick_price in range(hbt.best_bid_tick, hbt.low_bid_tick - 1, -1):
            if tick_price in hbt.bid_depth:
                bid_price = tick_price * hbt.tick_size
                depth_from_mid = (mid_price - bid_price) / mid_price
                if depth_from_mid > 0.01:
                    break
                sum_bid_qty += hbt.bid_depth[tick_price]
                
                if depth_from_mid <= 0.005:
                    sum_bid_qty_50bp = sum_bid_qty
                
        imbalance_50bp = sum_bid_qty_50bp - sum_ask_qty_50bp
        imbalance_1pct = sum_bid_qty - sum_ask_qty
        imbalance_tob = hbt.bid_depth[hbt.best_bid_tick] - hbt.ask_depth[hbt.best_ask_tick]
        
        out.append((hbt.current_timestamp, imbalance_tob, imbalance_50bp, imbalance_1pct))        
    return True

# %%
from numba.typed import List
from numba.types import Tuple, float64

hbt = HftBacktest(
    btcusdt_20230405,
    tick_size=0.1,
    lot_size=0.001,
    maker_fee=0.0002,
    taker_fee=0.0007,
    order_latency=FeedLatency(),
    asset_type=Linear,
    snapshot=btcusdt_20230404_eod
)

tup_ty = Tuple((float64, float64, float64, float64))
out = List.empty_list(tup_ty, allocated=100_000)

orderbookimbalance(hbt, out)
# Out:
# False

# %%
import polars as pl

df = pl.DataFrame(out).transpose()
df.columns = ['Local Timestamp', 'TOB Imbalance', '0.5% Imbalance', '1% Imbalance']
df = df.with_columns(
    pl.from_epoch('Local Timestamp', time_unit='us')
)

df
# Out:
# shape: (41, 4)
# ┌────────────────────────────┬───────────────┬────────────────┬──────────────┐
# │ Local Timestamp            ┆ TOB Imbalance ┆ 0.5% Imbalance ┆ 1% Imbalance │
# │ ---                        ┆ ---           ┆ ---            ┆ ---          │
# │ datetime[μs]               ┆ f64           ┆ f64            ┆ f64          │
# ╞════════════════════════════╪═══════════════╪════════════════╪══════════════╡
# │ 2023-04-05 00:00:10.032116 ┆ 10.62         ┆ 79.522         ┆ -521.026     │
# │ 2023-04-05 00:00:20.032116 ┆ -4.868        ┆ -152.592       ┆ -684.247     │
# │ 2023-04-05 00:00:30.032116 ┆ 0.59          ┆ -161.95        ┆ -701.843     │
# │ 2023-04-05 00:00:40.032116 ┆ 3.962         ┆ -142.51        ┆ -669.033     │
# │ …                          ┆ …             ┆ …              ┆ …            │
# │ 2023-04-05 00:06:20.032116 ┆ -5.273        ┆ 434.96         ┆ -1004.985    │
# │ 2023-04-05 00:06:30.032116 ┆ -4.487        ┆ 570.354        ┆ -837.517     │
# │ 2023-04-05 00:06:40.032116 ┆ -6.186        ┆ 565.936        ┆ -838.518     │
# │ 2023-04-05 00:06:50.032116 ┆ 3.351         ┆ 534.445        ┆ -870.112     │
# └────────────────────────────┴───────────────┴────────────────┴──────────────┘

# %%
import matplotlib.pyplot as plt

plt.plot(df['Local Timestamp'], df['TOB Imbalance'])
plt.plot(df['Local Timestamp'], df['0.5% Imbalance'])
plt.plot(df['Local Timestamp'], df['1% Imbalance'])

plt.legend(['TOB Imbalance', '0.5% Imbalance', '1% Imbalance'])

# %% [markdown]
# ## Display last trades between the step

# %%
from hftbacktest import COL_EXCH_TIMESTAMP, COL_SIDE, COL_PRICE, COL_QTY

@njit
def print_trades(hbt):
    while hbt.run:
        if not hbt.elapse(60 * 1e6):
            return False
        
        print('-------------------------------------------------------------------------------')
        print('current_timestamp:', hbt.current_timestamp)
        
        for trade in hbt.last_trades:
            print(
                'exch_timestamp:',
                trade[COL_EXCH_TIMESTAMP],
                'buy' if trade[COL_SIDE] == 1 else 'sell',
                trade[COL_QTY],
                '@',
                trade[COL_PRICE]
            )
        
        hbt.clear_last_trades()
    return True

# %%
hbt = HftBacktest(
    btcusdt_20230405,
    tick_size=0.1,
    lot_size=0.001,
    maker_fee=0.0002,
    taker_fee=0.0007,
    order_latency=FeedLatency(),
    asset_type=Linear,
    snapshot=btcusdt_20230404_eod,
    trade_list_size=10_000
)

print_trades(hbt)
# Out:
# -------------------------------------------------------------------------------
# current_timestamp: 1680652860032116
# exch_timestamp: 1680652804962000.0 sell 0.001 @ 28155.1
# exch_timestamp: 1680652804964000.0 buy 0.012 @ 28155.2
# exch_timestamp: 1680652804966000.0 buy 0.002 @ 28155.2
# exch_timestamp: 1680652804968000.0 buy 0.003 @ 28155.2
# exch_timestamp: 1680652804981000.0 sell 0.019 @ 28155.1
# exch_timestamp: 1680652804981000.0 sell 0.004 @ 28155.1
# exch_timestamp: 1680652804981000.0 sell 0.001 @ 28155.1
# exch_timestamp: 1680652804981000.0 sell 0.02 @ 28155.1
# exch_timestamp: 1680652804981000.0 sell 0.013 @ 28155.1
# exch_timestamp: 1680652804981000.0 sell 0.002 @ 28155.1
# exch_timestamp: 1680652804981000.0 sell 0.001 @ 28155.0
# exch_timestamp: 1680652804981000.0 sell 0.001 @ 28155.0
# exch_timestamp: 1680652804981000.0 sell 0.001 @ 28155.0
# exch_timestamp: 1680652804981000.0 sell 0.001 @ 28155.0
# exch_timestamp: 1680652804981000.0 sell 0.007 @ 28155.0
# exch_timestamp: 1680652804981000.0 sell 0.054 @ 28155.0
# exch_timestamp: 1680652805000000.0 sell 0.006 @ 28155.0
# exch_timestamp: 1680652805016000.0 buy 0.054 @ 28155.1
# exch_timestamp: 1680652805021000.0 sell 0.069 @ 28155.0
# exch_timestamp: 1680652805025000.0 sell 0.095 @ 28155.0
# exch_timestamp: 1680652805025000.0 sell 0.002 @ 28155.0
# exch_timestamp: 1680652805031000.0 buy 0.011 @ 28155.1
# exch_timestamp: 1680652805038000.0 sell 0.154 @ 28155.0
# exch_timestamp: 1680652805038000.0 sell 0.001 @ 28155.0
# exch_timestamp: 1680652805041000.0 buy 0.08 @ 28155.0
# exch_timestamp: 1680652805041000.0 buy 0.06 @ 28155.1
# exch_timestamp: 1680652805044000.0 buy 0.005 @ 28155.1
# exch_timestamp: 1680652805051000.0 sell 0.137 @ 28154.8
# exch_timestamp: 1680652805051000.0 sell 0.001 @ 28154.7
# exch_timestamp: 1680652805051000.0 sell 0.001 @ 28154.7
# exch_timestamp: 1680652805051000.0 sell 0.001 @ 28154.6
# exch_timestamp: 1680652805051000.0 sell 0.001 @ 28154.6
# exch_timestamp: 1680652805051000.0 sell 0.001 @ 28154.6
# exch_timestamp: 1680652805051000.0 sell 0.001 @ 28154.5
# exch_timestamp: 1680652805051000.0 sell 0.005 @ 28154.5
# exch_timestamp: 1680652805051000.0 sell 0.001 @ 28154.4
# exch_timestamp: 1680652805051000.0 sell 0.001 @ 28154.4
# exch_timestamp: 1680652805051000.0 sell 0.06 @ 28154.4
# exch_timestamp: 1680652805051000.0 sell 0.001 @ 28154.2
# exch_timestamp: 1680652805051000.0 sell 0.001 @ 28154.2
# exch_timestamp: 1680652805051000.0 sell 0.013 @ 28154.2
# exch_timestamp: 1680652805051000.0 sell 0.001 @ 28154.2
# exch_timestamp: 1680652805051000.0 sell 0.008 @ 28154.2
# exch_timestamp: 1680652805051000.0 sell 0.001 @ 28154.1
# exch_timestamp: 1680652805051000.0 sell 0.002 @ 28154.1
# exch_timestamp: 1680652805051000.0 sell 0.001 @ 28154.1
# exch_timestamp: 1680652805051000.0 sell 0.16 @ 28154.0
# exch_timestamp: 1680652805051000.0 sell 0.001 @ 28154.0
# exch_timestamp: 1680652805051000.0 sell 0.001 @ 28153.9
# exch_timestamp: 1680652805051000.0 sell 0.001 @ 28153.9
# exch_timestamp: 1680652805051000.0 sell 0.001 @ 28153.8
# exch_timestamp: 1680652805051000.0 sell 0.001 @ 28153.7
# exch_timestamp: 1680652805051000.0 sell 0.001 @ 28153.6
# exch_timestamp: 1680652805051000.0 sell 0.001 @ 28153.6
# exch_timestamp: 1680652805051000.0 sell 0.033 @ 28153.6
# exch_timestamp: 1680652805051000.0 sell 0.001 @ 28153.5
# exch_timestamp: 1680652805051000.0 sell 0.005 @ 28153.5
# exch_timestamp: 1680652805051000.0 sell 0.02 @ 28153.3
# exch_timestamp: 1680652805051000.0 sell 0.013 @ 28153.2
# exch_timestamp: 1680652805051000.0 sell 0.008 @ 28153.2
# exch_timestamp: 1680652805051000.0 sell 0.001 @ 28153.1
# exch_timestamp: 1680652805051000.0 sell 0.115 @ 28153.1
# exch_timestamp: 1680652805051000.0 sell 0.334 @ 28153.0
# exch_timestamp: 1680652805051000.0 sell 0.315 @ 28153.0
# exch_timestamp: 1680652805055000.0 buy 0.005 @ 28153.1
# exch_timestamp: 1680652805055000.0 buy 0.017 @ 28153.1
# exch_timestamp: 1680652805055000.0 buy 0.005 @ 28153.2
# exch_timestamp: 1680652805055000.0 buy 0.017 @ 28153.2
# exch_timestamp: 1680652805055000.0 buy 0.005 @ 28153.3
# exch_timestamp: 1680652805055000.0 buy 0.017 @ 28153.3
# exch_timestamp: 1680652805055000.0 buy 0.005 @ 28153.4
# exch_timestamp: 1680652805055000.0 buy 0.01 @ 28153.4
# exch_timestamp: 1680652805056000.0 buy 0.007 @ 28153.4
# exch_timestamp: 1680652805056000.0 buy 0.005 @ 28153.5
# exch_timestamp: 1680652805056000.0 buy 0.003 @ 28153.5
# exch_timestamp: 1680652805059000.0 sell 0.006 @ 28153.0
# exch_timestamp: 1680652805059000.0 sell 0.003 @ 28153.0
# exch_timestamp: 1680652805075000.0 sell 0.015 @ 28153.0
# exch_timestamp: 1680652805077000.0 buy 0.001 @ 28153.5
# exch_timestamp: 1680652805079000.0 sell 0.088 @ 28153.0
# exch_timestamp: 1680652805079000.0 sell 0.003 @ 28152.9
# exch_timestamp: 1680652805079000.0 sell 0.001 @ 28152.9
# exch_timestamp: 1680652805079000.0 sell 0.001 @ 28152.9
# exch_timestamp: 1680652805079000.0 sell 0.025 @ 28152.9
# exch_timestamp: 1680652805083000.0 buy 0.001 @ 28153.5
# exch_timestamp: 1680652805094000.0 buy 0.012 @ 28153.5
# exch_timestamp: 1680652805094000.0 buy 0.076 @ 28153.6
# exch_timestamp: 1680652805103000.0 buy 0.004 @ 28153.6
# exch_timestamp: 1680652805107000.0 buy 0.023 @ 28153.6
# exch_timestamp: 1680652805107000.0 sell 0.005 @ 28153.3
# exch_timestamp: 1680652805108000.0 buy 0.004 @ 28153.6
# exch_timestamp: 1680652805109000.0 buy 0.053 @ 28153.6
# exch_timestamp: 1680652805111000.0 sell 0.002 @ 28153.3
# exch_timestamp: 1680652805111000.0 sell 0.003 @ 28152.9
# exch_timestamp: 1680652805113000.0 sell 0.009 @ 28152.9
# exch_timestamp: 1680652805116000.0 buy 0.002 @ 28153.6
# exch_timestamp: 1680652805116000.0 buy 0.014 @ 28153.6
# exch_timestamp: 1680652805117000.0 buy 0.042 @ 28153.6
# exch_timestamp: 1680652805120000.0 buy 0.011 @ 28153.6
# exch_timestamp: 1680652805121000.0 sell 0.004 @ 28152.9
# exch_timestamp: 1680652805126000.0 sell 0.123 @ 28152.9
# exch_timestamp: 1680652805128000.0 buy 0.04 @ 28153.6
# exch_timestamp: 1680652805128000.0 buy 0.005 @ 28153.6
# exch_timestamp: 1680652805128000.0 buy 0.017 @ 28153.6
# exch_timestamp: 1680652805128000.0 buy 0.005 @ 28153.7
# exch_timestamp: 1680652805128000.0 buy 0.017 @ 28153.7
# exch_timestamp: 1680652805128000.0 buy 0.092 @ 28153.7
# exch_timestamp: 1680652805133000.0 buy 0.12 @ 28153.7
# exch_timestamp: 1680652805133000.0 buy 0.005 @ 28153.8
# exch_timestamp: 1680652805133000.0 buy 0.017 @ 28153.8
# exch_timestamp: 1680652805133000.0 buy 0.025 @ 28153.9
# exch_timestamp: 1680652805141000.0 sell 0.283 @ 28152.9
# exch_timestamp: 1680652805141000.0 buy 0.137 @ 28153.9
# exch_timestamp: 1680652805141000.0 buy 0.099 @ 28153.9
# exch_timestamp: 1680652805141000.0 buy 0.107 @ 28153.9
# exch_timestamp: 1680652805141000.0 buy 0.101 @ 28153.9
# exch_timestamp: 1680652805141000.0 buy 0.005 @ 28153.9
# exch_timestamp: 1680652805141000.0 buy 0.017 @ 28153.9
# exch_timestamp: 1680652805142000.0 buy 0.005 @ 28154.0
# exch_timestamp: 1680652805142000.0 buy 0.017 @ 28154.0
# exch_timestamp: 1680652805142000.0 buy 0.212 @ 28154.0
# exch_timestamp: 1680652805142000.0 buy 0.077 @ 28154.0
# exch_timestamp: 1680652805144000.0 buy 0.008 @ 28154.0
# exch_timestamp: 1680652805151000.0 buy 0.054 @ 28154.0
# exch_timestamp: 1680652805165000.0 buy 0.073 @ 28154.0
# exch_timestamp: 1680652805165000.0 buy 0.055 @ 28154.1
# exch_timestamp: 1680652805165000.0 buy 0.107 @ 28154.1
# exch_timestamp: 1680652805165000.0 buy 0.099 @ 28154.1
# exch_timestamp: 1680652805165000.0 buy 0.107 @ 28154.1
# exch_timestamp: 1680652805165000.0 buy 0.005 @ 28154.1
# exch_timestamp: 1680652805165000.0 buy 0.095 @ 28154.1
# exch_timestamp: 1680652805165000.0 buy 0.099 @ 28154.1
# exch_timestamp: 1680652805165000.0 buy 0.107 @ 28154.1
# exch_timestamp: 1680652805165000.0 buy 0.017 @ 28154.1
# exch_timestamp: 1680652805165000.0 buy 0.212 @ 28154.1
# exch_timestamp: 1680652805165000.0 buy 0.099 @ 28154.1
# exch_timestamp: 1680652805165000.0 buy 0.003 @ 28154.1
# exch_timestamp: 1680652805165000.0 buy 0.212 @ 28154.1
# exch_timestamp: 1680652805165000.0 buy 0.005 @ 28154.2
# exch_timestamp: 1680652805165000.0 buy 0.017 @ 28154.2
# exch_timestamp: 1680652805165000.0 buy 0.212 @ 28154.2
# exch_timestamp: 1680652805165000.0 buy 0.212 @ 28154.2
# exch_timestamp: 1680652805165000.0 buy 0.002 @ 28154.2
# exch_timestamp: 1680652805165000.0 buy 0.162 @ 28154.3
# exch_timestamp: 1680652805165000.0 buy 0.099 @ 28154.3
# exch_timestamp: 1680652805165000.0 buy 0.026 @ 28154.3
# exch_timestamp: 1680652805165000.0 buy 0.001 @ 28154.3
# exch_timestamp: 1680652805170000.0 sell 0.019 @ 28153.7
# exch_timestamp: 1680652805170000.0 sell 0.003 @ 28153.5
# exch_timestamp: 1680652805170000.0 sell 0.05 @ 28152.9
# exch_timestamp: 1680652805170000.0 buy 0.001 @ 28154.3
# exch_timestamp: 1680652805176000.0 buy 0.019 @ 28154.3
# exch_timestamp: 1680652805176000.0 buy 0.005 @ 28154.3
# exch_timestamp: 1680652805176000.0 buy 0.012 @ 28154.3
# exch_timestamp: 1680652805176000.0 buy 0.056 @ 28154.3
# exch_timestamp: 1680652805180000.0 sell 0.002 @ 28152.9
# exch_timestamp: 1680652805183000.0 sell 0.001 @ 28152.9
# exch_timestamp: 1680652805183000.0 sell 0.001 @ 28152.6
# exch_timestamp: 1680652805183000.0 sell 0.001 @ 28152.6
# exch_timestamp: 1680652805183000.0 sell 0.001 @ 28152.6
# exch_timestamp: 1680652805183000.0 sell 0.002 @ 28152.3
# exch_timestamp: 1680652805183000.0 sell 0.001 @ 28152.1
# exch_timestamp: 1680652805183000.0 sell 0.16 @ 28152.0
# exch_timestamp: 1680652805183000.0 sell 0.135 @ 28152.0
# exch_timestamp: 1680652805184000.0 buy 0.148 @ 28152.1
# exch_timestamp: 1680652805189000.0 sell 0.007 @ 28152.0
# exch_timestamp: 1680652805190000.0 sell 0.002 @ 28152.0
# exch_timestamp: 1680652805193000.0 sell 0.084 @ 28152.0
# exch_timestamp: 1680652805197000.0 sell 0.16 @ 28152.0
# exch_timestamp: 1680652805200000.0 sell 0.051 @ 28152.0
# exch_timestamp: 1680652805204000.0 sell 0.005 @ 28152.0
# exch_timestamp: 1680652805207000.0 sell 0.001 @ 28152.0
# exch_timestamp: 1680652805210000.0 sell 0.028 @ 28152.0
# exch_timestamp: 1680652805212000.0 sell 0.074 @ 28152.0
# exch_timestamp: 1680652805217000.0 sell 0.001 @ 28152.0
# exch_timestamp: 1680652805220000.0 sell 0.008 @ 28152.0
# exch_timestamp: 1680652805280000.0 sell 0.001 @ 28152.0
# exch_timestamp: 1680652805315000.0 sell 0.002 @ 28152.0
# exch_timestamp: 1680652805334000.0 sell 0.046 @ 28152.0
# exch_timestamp: 1680652805340000.0 sell 0.005 @ 28152.0
# exch_timestamp: 1680652805340000.0 sell 0.368 @ 28152.0
# exch_timestamp: 1680652805354000.0 buy 0.152 @ 28152.1
# exch_timestamp: 1680652805354000.0 buy 0.102 @ 28152.1
# exch_timestamp: 1680652805354000.0 buy 0.017 @ 28152.1
# exch_timestamp: 1680652805354000.0 buy 0.017 @ 28152.2
# exch_timestamp: 1680652805354000.0 buy 0.017 @ 28152.3
# exch_timestamp: 1680652805354000.0 buy 0.017 @ 28152.4
# exch_timestamp: 1680652805354000.0 buy 0.001 @ 28152.4
# exch_timestamp: 1680652805354000.0 buy 0.017 @ 28152.5
# exch_timestamp: 1680652805354000.0 buy 0.017 @ 28152.6
# exch_timestamp: 1680652805355000.0 buy 0.005 @ 28152.7
# exch_timestamp: 1680652805355000.0 buy 0.006 @ 28152.7
# exch_timestamp: 1680652805364000.0 sell 0.012 @ 28152.0
# exch_timestamp: 1680652805364000.0 sell 0.001 @ 28152.0
# exch_timestamp: 1680652805364000.0 sell 0.202 @ 28151.8
# exch_timestamp: 1680652805364000.0 sell 0.046 @ 28151.8
# exch_timestamp: 1680652805376000.0 buy 0.001 @ 28151.9
# exch_timestamp: 1680652805387000.0 sell 0.016 @ 28151.8
# exch_timestamp: 1680652805390000.0 buy 0.001 @ 28151.9
# exch_timestamp: 1680652805404000.0 sell 0.012 @ 28151.8
# exch_timestamp: 1680652805410000.0 buy 0.002 @ 28151.9
# exch_timestamp: 1680652805436000.0 sell 0.464 @ 28151.8
# exch_timestamp: 1680652805437000.0 sell 0.001 @ 28151.8
# exch_timestamp: 1680652805472000.0 buy 0.002 @ 28151.9
# exch_timestamp: 1680652805500000.0 buy 0.005 @ 28151.9
# exch_timestamp: 1680652805502000.0 buy 0.006 @ 28151.9
# exch_timestamp: 1680652805511000.0 buy 0.016 @ 28151.9
# exch_timestamp: 1680652805539000.0 buy 0.002 @ 28151.9
# exch_timestamp: 1680652805541000.0 buy 0.002 @ 28151.9
# exch_timestamp: 1680652805541000.0 buy 0.003 @ 28151.9
# exch_timestamp: 1680652805592000.0 sell 0.004 @ 28151.8
# exch_timestamp: 1680652805595000.0 buy 0.039 @ 28151.9
# exch_timestamp: 1680652805596000.0 sell 0.005 @ 28151.8
# exch_timestamp: 1680652805598000.0 sell 0.011 @ 28151.8
# exch_timestamp: 1680652805598000.0 buy 0.007 @ 28151.9
# exch_timestamp: 1680652805614000.0 sell 0.027 @ 28151.8
# exch_timestamp: 1680652805614000.0 buy 0.024 @ 28151.9
# exch_timestamp: 1680652805624000.0 buy 0.009 @ 28151.9
# exch_timestamp: 1680652805664000.0 sell 0.015 @ 28151.8
# exch_timestamp: 1680652805764000.0 sell 0.06 @ 28151.8
# exch_timestamp: 1680652805764000.0 sell 0.02 @ 28151.8
# exch_timestamp: 1680652805764000.0 sell 0.001 @ 28151.8
# exch_timestamp: 1680652805764000.0 sell 0.02 @ 28151.8
# exch_timestamp: 1680652805764000.0 sell 0.001 @ 28151.6
# exch_timestamp: 1680652805764000.0 sell 0.011 @ 28151.5
# exch_timestamp: 1680652805764000.0 sell 0.022 @ 28151.5
# exch_timestamp: 1680652805767000.0 buy 0.01 @ 28151.6
# exch_timestamp: 1680652805875000.0 sell 0.014 @ 28151.5
# exch_timestamp: 1680652805875000.0 sell 0.001 @ 28151.5
# exch_timestamp: 1680652805875000.0 sell 0.02 @ 28151.5
# exch_timestamp: 1680652805875000.0 sell 0.177 @ 28151.3
# exch_timestamp: 1680652805875000.0 sell 0.05 @ 28151.2
# exch_timestamp: 1680652805875000.0 sell 0.001 @ 28151.1
# exch_timestamp: 1680652805875000.0 sell 0.001 @ 28151.0
# exch_timestamp: 1680652805875000.0 sell 0.003 @ 28151.0
# exch_timestamp: 1680652805875000.0 sell 0.224 @ 28151.0
# exch_timestamp: 1680652806008000.0 sell 0.017 @ 28151.0
# exch_timestamp: 1680652806054000.0 sell 0.083 @ 28151.0
# exch_timestamp: 1680652806056000.0 sell 0.046 @ 28151.0
# exch_timestamp: 1680652806063000.0 sell 0.057 @ 28151.0
# exch_timestamp: 1680652806147000.0 sell 0.009 @ 28151.0
# exch_timestamp: 1680652806147000.0 sell 0.001 @ 28151.0
# exch_timestamp: 1680652806147000.0 sell 0.02 @ 28151.0
# exch_timestamp: 1680652806147000.0 sell 0.02 @ 28151.0
# exch_timestamp: 1680652806147000.0 sell 0.912 @ 28151.0
# exch_timestamp: 1680652806147000.0 sell 0.002 @ 28150.9
# exch_timestamp: 1680652806147000.0 sell 0.008 @ 28150.9
# exch_timestamp: 1680652806147000.0 sell 0.43 @ 28150.9
# exch_timestamp: 1680652806147000.0 sell 0.035 @ 28150.9
# exch_timestamp: 1680652806147000.0 sell 0.171 @ 28150.7
# exch_timestamp: 1680652806153000.0 sell 0.007 @ 28150.7
# exch_timestamp: 1680652806153000.0 sell 0.001 @ 28150.7
# exch_timestamp: 1680652806153000.0 sell 0.01 @ 28150.7
# exch_timestamp: 1680652806153000.0 sell 0.001 @ 28150.6
# exch_timestamp: 1680652806153000.0 sell 0.113 @ 28150.4
# exch_timestamp: 1680652806164000.0 sell 0.001 @ 28150.4
# exch_timestamp: 1680652806250000.0 sell 0.064 @ 28150.4
# exch_timestamp: 1680652806250000.0 sell 0.001 @ 28150.4
# exch_timestamp: 1680652806250000.0 sell 0.02 @ 28150.4
# exch_timestamp: 1680652806250000.0 sell 0.283 @ 28150.3
# exch_timestamp: 1680652806445000.0 sell 0.835 @ 28150.3
# exch_timestamp: 1680652806484000.0 sell 0.004 @ 28150.3
# exch_timestamp: 1680652806541000.0 buy 0.009 @ 28150.4
# exch_timestamp: 1680652806595000.0 sell 0.026 @ 28150.3
# exch_timestamp: 1680652806692000.0 buy 0.004 @ 28150.4
# exch_timestamp: 1680652806709000.0 buy 0.012 @ 28150.4
# exch_timestamp: 1680652806875000.0 sell 0.016 @ 28150.3
# exch_timestamp: 1680652806875000.0 sell 0.28 @ 28150.3
# exch_timestamp: 1680652806990000.0 buy 0.009 @ 28150.4
# exch_timestamp: 1680652807090000.0 buy 0.001 @ 28150.4
# exch_timestamp: 1680652807106000.0 sell 0.001 @ 28150.3
# exch_timestamp: 1680652807106000.0 sell 0.02 @ 28150.3
# exch_timestamp: 1680652807106000.0 sell 0.02 @ 28150.3
# exch_timestamp: 1680652807106000.0 sell 0.012 @ 28150.2
# exch_timestamp: 1680652807106000.0 sell 0.018 @ 28150.2
# exch_timestamp: 1680652807252000.0 sell 0.086 @ 28150.2
# exch_timestamp: 1680652807689000.0 buy 0.158 @ 28150.3
# exch_timestamp: 1680652807807000.0 sell 0.001 @ 28150.2
# exch_timestamp: 1680652807807000.0 sell 0.002 @ 28150.2
# exch_timestamp: 1680652807822000.0 buy 0.001 @ 28150.3
# exch_timestamp: 1680652807853000.0 sell 0.009 @ 28150.2
# exch_timestamp: 1680652807854000.0 buy 0.063 @ 28150.3
# exch_timestamp: 1680652807872000.0 buy 0.196 @ 28150.3
# exch_timestamp: 1680652807872000.0 buy 0.007 @ 28150.3
# exch_timestamp: 1680652807874000.0 sell 0.009 @ 28150.2
# exch_timestamp: 1680652807874000.0 sell 0.02 @ 28150.2
# exch_timestamp: 1680652807874000.0 sell 0.02 @ 28150.2
# exch_timestamp: 1680652807874000.0 sell 0.096 @ 28150.2
# exch_timestamp: 1680652807950000.0 buy 0.005 @ 28150.3
# exch_timestamp: 1680652808020000.0 sell 0.074 @ 28150.2
# exch_timestamp: 1680652808046000.0 buy 0.003 @ 28150.3
# exch_timestamp: 1680652808072000.0 sell 0.003 @ 28150.2
# exch_timestamp: 1680652808116000.0 sell 0.129 @ 28150.2
# exch_timestamp: 1680652808188000.0 buy 0.005 @ 28150.3
# exch_timestamp: 1680652808188000.0 buy 0.006 @ 28150.3
# exch_timestamp: 1680652808206000.0 buy 0.001 @ 28150.3
# exch_timestamp: 1680652808210000.0 buy 0.013 @ 28150.3
# exch_timestamp: 1680652808210000.0 buy 0.001 @ 28150.3
# exch_timestamp: 1680652808210000.0 buy 0.012 @ 28150.3
# exch_timestamp: 1680652808210000.0 buy 0.02 @ 28150.3
# exch_timestamp: 1680652808210000.0 buy 0.003 @ 28150.4
# exch_timestamp: 1680652808214000.0 buy 0.001 @ 28151.1
# exch_timestamp: 1680652808455000.0 sell 0.003 @ 28151.0
# exch_timestamp: 1680652808483000.0 sell 0.004 @ 28151.0
# exch_timestamp: 1680652808483000.0 buy 0.007 @ 28151.1
# exch_timestamp: 1680652808488000.0 sell 0.05 @ 28151.0
# exch_timestamp: 1680652808590000.0 buy 0.006 @ 28151.1
# exch_timestamp: 1680652808590000.0 buy 0.001 @ 28151.1
# exch_timestamp: 1680652808590000.0 buy 0.02 @ 28151.1
# exch_timestamp: 1680652808590000.0 buy 0.018 @ 28151.1
# exch_timestamp: 1680652808623000.0 sell 0.155 @ 28151.0
# exch_timestamp: 1680652808623000.0 sell 0.001 @ 28151.0
# exch_timestamp: 1680652808623000.0 sell 0.056 @ 28151.0
# exch_timestamp: 1680652808636000.0 buy 0.014 @ 28151.1
# exch_timestamp: 1680652808712000.0 buy 0.006 @ 28151.1
# exch_timestamp: 1680652808712000.0 buy 0.001 @ 28151.1
# exch_timestamp: 1680652808712000.0 buy 0.02 @ 28151.1
# exch_timestamp: 1680652808712000.0 buy 0.008 @ 28151.2
# exch_timestamp: 1680652808722000.0 buy 0.008 @ 28151.5
# exch_timestamp: 1680652808726000.0 buy 0.002 @ 28151.6
# exch_timestamp: 1680652808727000.0 buy 0.026 @ 28151.9
# exch_timestamp: 1680652808727000.0 buy 0.015 @ 28151.9
# exch_timestamp: 1680652808727000.0 buy 0.004 @ 28151.9
# exch_timestamp: 1680652808740000.0 sell 0.099 @ 28152.0
# exch_timestamp: 1680652808740000.0 sell 0.107 @ 28152.0
# exch_timestamp: 1680652808740000.0 sell 0.107 @ 28152.0
# exch_timestamp: 1680652808740000.0 sell 0.021 @ 28152.0
# exch_timestamp: 1680652808740000.0 sell 0.107 @ 28152.0
# exch_timestamp: 1680652808740000.0 sell 0.107 @ 28152.0
# exch_timestamp: 1680652808740000.0 sell 0.099 @ 28152.0
# exch_timestamp: 1680652808740000.0 sell 0.5 @ 28152.0
# exch_timestamp: 1680652808740000.0 sell 0.124 @ 28152.0
# exch_timestamp: 1680652808740000.0 sell 0.676 @ 28152.0
# exch_timestamp: 1680652808742000.0 buy 0.48 @ 28152.1
# exch_timestamp: 1680652808742000.0 buy 0.001 @ 28152.1
# exch_timestamp: 1680652808742000.0 buy 0.027 @ 28152.1
# exch_timestamp: 1680652808742000.0 buy 0.001 @ 28152.1
# exch_timestamp: 1680652808770000.0 buy 0.008 @ 28152.2
# exch_timestamp: 1680652808818000.0 sell 0.001 @ 28152.1
# exch_timestamp: 1680652808878000.0 sell 0.102 @ 28152.1
# exch_timestamp: 1680652808907000.0 sell 0.004 @ 28152.1
# exch_timestamp: 1680652808907000.0 sell 0.017 @ 28152.1
# exch_timestamp: 1680652808915000.0 buy 0.003 @ 28152.2
# exch_timestamp: 1680652808937000.0 sell 0.002 @ 28152.1
# exch_timestamp: 1680652809031000.0 buy 0.001 @ 28152.2
# exch_timestamp: 1680652809031000.0 buy 0.003 @ 28152.2
# exch_timestamp: 1680652809046000.0 sell 0.089 @ 28152.1
# exch_timestamp: 1680652809046000.0 sell 0.057 @ 28152.1
# exch_timestamp: 1680652809070000.0 sell 0.003 @ 28152.1
# exch_timestamp: 1680652809076000.0 buy 0.003 @ 28152.2
# exch_timestamp: 1680652809253000.0 sell 0.004 @ 28152.1
# exch_timestamp: 1680652809258000.0 sell 0.032 @ 28152.1
# exch_timestamp: 1680652809386000.0 buy 0.002 @ 28152.2
# exch_timestamp: 1680652809509000.0 sell 0.003 @ 28152.1
# exch_timestamp: 1680652809509000.0 sell 0.021 @ 28152.1
# exch_timestamp: 1680652809509000.0 sell 0.012 @ 28152.1
# exch_timestamp: 1680652809521000.0 buy 0.002 @ 28152.2
# exch_timestamp: 1680652809532000.0 sell 0.008 @ 28152.1
# exch_timestamp: 1680652809621000.0 sell 0.009 @ 28152.1
# exch_timestamp: 1680652809649000.0 buy 0.01 @ 28152.2
# exch_timestamp: 1680652809649000.0 buy 0.02 @ 28152.2
# exch_timestamp: 1680652809649000.0 buy 0.013 @ 28152.2
# exch_timestamp: 1680652809649000.0 buy 0.001 @ 28152.2
# exch_timestamp: 1680652809649000.0 buy 0.547 @ 28152.2
# exch_timestamp: 1680652809650000.0 buy 0.003 @ 28152.2
# exch_timestamp: 1680652809650000.0 buy 0.085 @ 28152.2
# exch_timestamp: 1680652809661000.0 buy 0.09 @ 28152.2
# exch_timestamp: 1680652809661000.0 buy 0.048 @ 28152.2
# exch_timestamp: 1680652809671000.0 buy 0.115 @ 28152.2
# exch_timestamp: 1680652809671000.0 buy 0.023 @ 28152.2
# exch_timestamp: 1680652809674000.0 sell 0.028 @ 28152.1
# exch_timestamp: 1680652809686000.0 buy 0.016 @ 28152.2
# exch_timestamp: 1680652809686000.0 buy 0.071 @ 28152.2
# exch_timestamp: 1680652809710000.0 buy 0.007 @ 28152.2
# exch_timestamp: 1680652809757000.0 buy 0.003 @ 28152.2
# exch_timestamp: 1680652809871000.0 buy 0.2 @ 28152.2
# exch_timestamp: 1680652809874000.0 buy 0.047 @ 28152.2
# exch_timestamp: 1680652809874000.0 buy 0.122 @ 28152.2
# exch_timestamp: 1680652809874000.0 buy 0.031 @ 28152.2
# exch_timestamp: 1680652809874000.0 buy 0.015 @ 28152.2
# exch_timestamp: 1680652809874000.0 buy 0.185 @ 28152.2
# exch_timestamp: 1680652809906000.0 sell 0.017 @ 28152.1
# exch_timestamp: 1680652810038000.0 sell 0.02 @ 28152.1
# exch_timestamp: 1680652810062000.0 sell 0.013 @ 28152.1
# exch_timestamp: 1680652810062000.0 sell 0.107 @ 28152.1
# exch_timestamp: 1680652810062000.0 sell 0.099 @ 28152.1
# exch_timestamp: 1680652810062000.0 sell 0.107 @ 28152.1
# exch_timestamp: 1680652810062000.0 sell 0.021 @ 28152.1
# exch_timestamp: 1680652810062000.0 sell 0.107 @ 28152.1
# exch_timestamp: 1680652810062000.0 sell 0.035 @ 28152.1
# exch_timestamp: 1680652810062000.0 sell 0.124 @ 28152.1
# exch_timestamp: 1680652810062000.0 sell 0.054 @ 28152.1
# exch_timestamp: 1680652810065000.0 sell 0.005 @ 28152.1
# exch_timestamp: 1680652810337000.0 sell 0.004 @ 28152.1
# exch_timestamp: 1680652810496000.0 sell 0.177 @ 28152.1
# exch_timestamp: 1680652810698000.0 sell 0.431 @ 28152.1
# exch_timestamp: 1680652810698000.0 sell 1.657 @ 28152.1
# exch_timestamp: 1680652810698000.0 sell 0.02 @ 28152.1
# exch_timestamp: 1680652810698000.0 sell 0.02 @ 28152.1
# exch_timestamp: 1680652810698000.0 sell 0.001 @ 28152.1
# exch_timestamp: 1680652810698000.0 sell 0.636 @ 28152.1
# exch_timestamp: 1680652810698000.0 sell 0.216 @ 28152.1
# exch_timestamp: 1680652810714000.0 sell 0.005 @ 28152.1
# exch_timestamp: 1680652810714000.0 sell 0.002 @ 28152.1
# exch_timestamp: 1680652810830000.0 sell 0.025 @ 28152.1
# exch_timestamp: 1680652810888000.0 sell 0.226 @ 28152.1
# exch_timestamp: 1680652811117000.0 sell 0.003 @ 28152.1
# exch_timestamp: 1680652811162000.0 buy 0.002 @ 28152.2
# exch_timestamp: 1680652811412000.0 buy 0.004 @ 28152.2
# exch_timestamp: 1680652811412000.0 buy 0.034 @ 28152.2
# exch_timestamp: 1680652811413000.0 buy 0.026 @ 28152.2
# exch_timestamp: 1680652811413000.0 buy 0.001 @ 28152.2
# exch_timestamp: 1680652811413000.0 buy 0.02 @ 28152.2
# exch_timestamp: 1680652811413000.0 buy 0.02 @ 28152.2
# exch_timestamp: 1680652811413000.0 buy 0.001 @ 28152.2
# exch_timestamp: 1680652811413000.0 buy 0.032 @ 28152.2
# exch_timestamp: 1680652811413000.0 buy 0.558 @ 28152.2
# exch_timestamp: 1680652811413000.0 buy 0.004 @ 28152.2
# exch_timestamp: 1680652811413000.0 buy 0.006 @ 28152.2
# exch_timestamp: 1680652811413000.0 buy 0.001 @ 28152.2
# exch_timestamp: 1680652811413000.0 buy 0.051 @ 28152.2
# exch_timestamp: 1680652811413000.0 buy 0.024 @ 28152.2
# exch_timestamp: 1680652811413000.0 buy 0.018 @ 28152.2
# exch_timestamp: 1680652811413000.0 buy 0.001 @ 28152.2
# exch_timestamp: 1680652811413000.0 buy 0.025 @ 28152.2
# exch_timestamp: 1680652811413000.0 buy 0.002 @ 28152.2
# exch_timestamp: 1680652811413000.0 buy 0.007 @ 28152.2
# exch_timestamp: 1680652811413000.0 buy 0.006 @ 28152.2
# exch_timestamp: 1680652811418000.0 buy 0.001 @ 28152.2
# exch_timestamp: 1680652811418000.0 buy 0.403 @ 28152.2
# exch_timestamp: 1680652811418000.0 buy 0.27 @ 28152.2
# exch_timestamp: 1680652811418000.0 buy 0.357 @ 28152.2
# exch_timestamp: 1680652811418000.0 buy 0.015 @ 28152.2
# exch_timestamp: 1680652811418000.0 buy 0.002 @ 28152.2
# exch_timestamp: 1680652811432000.0 buy 0.001 @ 28152.3
# exch_timestamp: 1680652811432000.0 buy 0.008 @ 28152.6
# exch_timestamp: 1680652811432000.0 buy 0.001 @ 28152.6
# exch_timestamp: 1680652811432000.0 buy 0.107 @ 28152.7
# exch_timestamp: 1680652811433000.0 buy 0.393 @ 28152.7
# exch_timestamp: 1680652811433000.0 buy 0.002 @ 28152.7
# exch_timestamp: 1680652811433000.0 buy 0.01 @ 28152.9
# exch_timestamp: 1680652811450000.0 buy 0.008 @ 28153.1
# exch_timestamp: 1680652811482000.0 buy 0.007 @ 28153.3
# exch_timestamp: 1680652811586000.0 sell 0.004 @ 28153.2
# exch_timestamp: 1680652811598000.0 buy 0.009 @ 28153.3
# exch_timestamp: 1680652811606000.0 sell 0.01 @ 28153.2
# exch_timestamp: 1680652811714000.0 buy 0.02 @ 28153.3
# exch_timestamp: 1680652811762000.0 sell 0.011 @ 28153.2
# exch_timestamp: 1680652811789000.0 buy 0.004 @ 28153.3
# exch_timestamp: 1680652811789000.0 buy 0.009 @ 28153.3
# exch_timestamp: 1680652811818000.0 sell 0.006 @ 28153.2
# exch_timestamp: 1680652811911000.0 sell 0.028 @ 28153.2
# exch_timestamp: 1680652812020000.0 buy 0.025 @ 28153.3
# exch_timestamp: 1680652812048000.0 sell 0.034 @ 28153.2
# exch_timestamp: 1680652812070000.0 buy 0.003 @ 28153.3
# exch_timestamp: 1680652812112000.0 sell 0.171 @ 28153.2
# exch_timestamp: 1680652812209000.0 sell 0.001 @ 28153.2
# exch_timestamp: 1680652812339000.0 buy 0.035 @ 28153.3
# exch_timestamp: 1680652812339000.0 buy 0.001 @ 28153.3
# exch_timestamp: 1680652812339000.0 buy 0.014 @ 28153.3
# exch_timestamp: 1680652812339000.0 buy 0.02 @ 28153.3
# exch_timestamp: 1680652812339000.0 buy 0.02 @ 28153.3
# exch_timestamp: 1680652812339000.0 buy 0.024 @ 28153.3
# exch_timestamp: 1680652812540000.0 sell 0.014 @ 28153.2
# exch_timestamp: 1680652812606000.0 sell 0.011 @ 28153.2
# exch_timestamp: 1680652812710000.0 buy 0.001 @ 28153.3
# exch_timestamp: 1680652812740000.0 buy 0.001 @ 28153.3
# exch_timestamp: 1680652812740000.0 buy 0.004 @ 28153.3
# exch_timestamp: 1680652812740000.0 buy 0.001 @ 28153.3
# exch_timestamp: 1680652812740000.0 buy 0.034 @ 28153.3
# exch_timestamp: 1680652812811000.0 buy 0.135 @ 28153.3
# exch_timestamp: 1680652812811000.0 buy 0.001 @ 28153.3
# exch_timestamp: 1680652812811000.0 buy 0.001 @ 28153.3
# exch_timestamp: 1680652812811000.0 buy 0.02 @ 28153.3
# exch_timestamp: 1680652812811000.0 buy 0.02 @ 28153.3
# exch_timestamp: 1680652812811000.0 buy 0.018 @ 28153.3
# exch_timestamp: 1680652812812000.0 buy 0.012 @ 28153.3
# exch_timestamp: 1680652812812000.0 buy 0.005 @ 28153.3
# exch_timestamp: 1680652812812000.0 buy 0.004 @ 28153.3
# exch_timestamp: 1680652812812000.0 buy 0.005 @ 28153.3
# exch_timestamp: 1680652812812000.0 buy 0.011 @ 28153.3
# exch_timestamp: 1680652812812000.0 buy 0.009 @ 28153.3
# exch_timestamp: 1680652812812000.0 buy 0.001 @ 28153.5
# exch_timestamp: 1680652812812000.0 buy 0.003 @ 28153.9
# exch_timestamp: 1680652812812000.0 buy 0.001 @ 28154.0
# exch_timestamp: 1680652812812000.0 buy 0.004 @ 28154.0
# exch_timestamp: 1680652812812000.0 buy 0.001 @ 28154.2
# exch_timestamp: 1680652812812000.0 buy 0.008 @ 28154.2
# exch_timestamp: 1680652812812000.0 buy 0.017 @ 28154.5
# exch_timestamp: 1680652812812000.0 buy 0.001 @ 28154.5
# exch_timestamp: 1680652812812000.0 buy 0.008 @ 28154.5
# exch_timestamp: 1680652812812000.0 buy 0.011 @ 28154.6
# exch_timestamp: 1680652812812000.0 buy 0.004 @ 28154.7
# exch_timestamp: 1680652812812000.0 buy 0.004 @ 28154.8
# exch_timestamp: 1680652812812000.0 buy 0.004 @ 28154.9
# exch_timestamp: 1680652812812000.0 buy 0.001 @ 28154.9
# exch_timestamp: 1680652812812000.0 buy 0.013 @ 28154.9
# exch_timestamp: 1680652812812000.0 buy 0.004 @ 28154.9
# exch_timestamp: 1680652812812000.0 buy 0.001 @ 28155.0
# exch_timestamp: 1680652812812000.0 buy 0.036 @ 28155.0
# exch_timestamp: 1680652812812000.0 buy 0.038 @ 28155.1
# exch_timestamp: 1680652812812000.0 buy 0.035 @ 28155.1
# exch_timestamp: 1680652812812000.0 buy 0.009 @ 28155.2
# exch_timestamp: 1680652812812000.0 buy 0.001 @ 28155.2
# exch_timestamp: 1680652812812000.0 buy 0.001 @ 28155.2
# exch_timestamp: 1680652812812000.0 buy 0.006 @ 28155.2
# exch_timestamp: 1680652812812000.0 buy 0.047 @ 28155.2
# exch_timestamp: 1680652812814000.0 sell 0.002 @ 28155.1
# exch_timestamp: 1680652812828000.0 buy 0.001 @ 28155.2
# exch_timestamp: 1680652812843000.0 sell 0.009 @ 28155.1
# exch_timestamp: 1680652812940000.0 sell 0.005 @ 28155.1
# exch_timestamp: 1680652812940000.0 sell 0.02 @ 28155.1
# exch_timestamp: 1680652812940000.0 sell 0.002 @ 28155.1
# exch_timestamp: 1680652813015000.0 buy 0.027 @ 28155.2
# exch_timestamp: 1680652813033000.0 buy 0.005 @ 28155.2
# exch_timestamp: 1680652813145000.0 buy 0.274 @ 28155.2
# exch_timestamp: 1680652813225000.0 buy 0.015 @ 28155.2
# exch_timestamp: 1680652813282000.0 sell 0.269 @ 28155.1
# exch_timestamp: 1680652813319000.0 sell 0.029 @ 28155.1
# exch_timestamp: 1680652813319000.0 sell 0.052 @ 28155.1
# exch_timestamp: 1680652813415000.0 sell 0.004 @ 28155.1
# exch_timestamp: 1680652813568000.0 buy 0.003 @ 28155.2
# exch_timestamp: 1680652813640000.0 sell 0.001 @ 28155.1
# exch_timestamp: 1680652813722000.0 buy 0.123 @ 28155.2
# exch_timestamp: 1680652813825000.0 buy 0.012 @ 28155.2
# exch_timestamp: 1680652813889000.0 sell 0.243 @ 28155.1
# exch_timestamp: 1680652813889000.0 sell 0.201 @ 28155.1
# exch_timestamp: 1680652813923000.0 sell 0.099 @ 28155.1
# exch_timestamp: 1680652813923000.0 sell 0.3 @ 28155.1
# exch_timestamp: 1680652813923000.0 sell 0.3 @ 28155.1
# exch_timestamp: 1680652813923000.0 sell 0.3 @ 28155.1
# exch_timestamp: 1680652813923000.0 sell 0.289 @ 28155.1
# exch_timestamp: 1680652814231000.0 buy 0.203 @ 28155.2
# exch_timestamp: 1680652814231000.0 buy 0.184 @ 28155.2
# exch_timestamp: 1680652814328000.0 sell 0.011 @ 28155.1
# exch_timestamp: 1680652814328000.0 sell 0.3 @ 28155.1
# exch_timestamp: 1680652814328000.0 sell 0.3 @ 28155.1
# exch_timestamp: 1680652814328000.0 sell 0.3 @ 28155.1
# exch_timestamp: 1680652814328000.0 sell 0.105 @ 28155.1
# exch_timestamp: 1680652814486000.0 buy 0.014 @ 28155.2
# exch_timestamp: 1680652814563000.0 buy 0.005 @ 28155.2
# exch_timestamp: 1680652814575000.0 buy 0.001 @ 28155.2
# exch_timestamp: 1680652814650000.0 sell 0.195 @ 28155.1
# exch_timestamp: 1680652814650000.0 sell 0.3 @ 28155.1
# exch_timestamp: 1680652814650000.0 sell 0.671 @ 28155.1
# exch_timestamp: 1680652814650000.0 sell 0.02 @ 28155.1
# exch_timestamp: 1680652814650000.0 sell 0.814 @ 28155.1
# exch_timestamp: 1680652814713000.0 buy 0.133 @ 28155.2
# exch_timestamp: 1680652814778000.0 buy 0.373 @ 28155.2
# exch_timestamp: 1680652814778000.0 buy 0.002 @ 28155.2
# exch_timestamp: 1680652814778000.0 buy 0.009 @ 28155.2
# exch_timestamp: 1680652814778000.0 buy 0.004 @ 28155.2
# exch_timestamp: 1680652814834000.0 sell 0.053 @ 28155.1
# exch_timestamp: 1680652814883000.0 sell 0.178 @ 28155.1
# exch_timestamp: 1680652814944000.0 sell 0.002 @ 28155.1
# exch_timestamp: 1680652814967000.0 sell 0.289 @ 28155.1
# exch_timestamp: 1680652815019000.0 buy 0.005 @ 28155.2
# exch_timestamp: 1680652815019000.0 buy 0.002 @ 28155.2
# exch_timestamp: 1680652815020000.0 buy 0.001 @ 28155.2
# exch_timestamp: 1680652815020000.0 buy 0.009 @ 28155.2
# exch_timestamp: 1680652815020000.0 buy 0.014 @ 28155.2
# exch_timestamp: 1680652815020000.0 buy 0.005 @ 28155.2
# exch_timestamp: 1680652815020000.0 buy 0.006 @ 28155.2
# exch_timestamp: 1680652815020000.0 buy 0.004 @ 28155.2
# exch_timestamp: 1680652815020000.0 buy 0.001 @ 28155.2
# exch_timestamp: 1680652815020000.0 buy 0.001 @ 28155.2
# exch_timestamp: 1680652815020000.0 buy 0.002 @ 28155.2
# exch_timestamp: 1680652815020000.0 buy 0.009 @ 28155.2
# exch_timestamp: 1680652815020000.0 buy 0.021 @ 28155.2
# exch_timestamp: 1680652815020000.0 buy 0.005 @ 28155.2
# exch_timestamp: 1680652815020000.0 buy 0.001 @ 28155.2
# exch_timestamp: 1680652815020000.0 buy 0.002 @ 28155.2
# exch_timestamp: 1680652815020000.0 buy 0.006 @ 28155.2
# exch_timestamp: 1680652815020000.0 buy 0.014 @ 28155.2
# exch_timestamp: 1680652815020000.0 buy 0.03 @ 28155.2
# exch_timestamp: 1680652815020000.0 buy 0.151 @ 28155.2
# exch_timestamp: 1680652815020000.0 buy 0.001 @ 28155.2
# exch_timestamp: 1680652815020000.0 buy 0.001 @ 28155.2
# exch_timestamp: 1680652815020000.0 buy 0.004 @ 28155.2
# exch_timestamp: 1680652815020000.0 buy 0.001 @ 28155.2
# exch_timestamp: 1680652815020000.0 buy 0.002 @ 28155.2
# exch_timestamp: 1680652815020000.0 buy 0.001 @ 28155.2
# exch_timestamp: 1680652815028000.0 sell 0.57 @ 28155.1
# exch_timestamp: 1680652815029000.0 buy 0.003 @ 28155.2
# exch_timestamp: 1680652815029000.0 buy 0.001 @ 28155.2
# exch_timestamp: 1680652815029000.0 buy 0.001 @ 28155.2
# exch_timestamp: 1680652815029000.0 buy 0.02 @ 28155.2
# exch_timestamp: 1680652815029000.0 buy 0.02 @ 28155.2
# exch_timestamp: 1680652815029000.0 buy 0.178 @ 28155.2
# exch_timestamp: 1680652815029000.0 buy 0.002 @ 28155.2
# exch_timestamp: 1680652815029000.0 buy 0.004 @ 28155.2
# exch_timestamp: 1680652815029000.0 buy 0.002 @ 28155.2
# exch_timestamp: 1680652815029000.0 buy 0.001 @ 28155.2
# exch_timestamp: 1680652815029000.0 buy 0.009 @ 28155.2
# exch_timestamp: 1680652815029000.0 buy 0.303 @ 28155.2
# exch_timestamp: 1680652815029000.0 buy 0.004 @ 28155.2
# exch_timestamp: 1680652815029000.0 buy 0.007 @ 28155.2
# exch_timestamp: 1680652815029000.0 buy 0.012 @ 28155.2
# exch_timestamp: 1680652815029000.0 buy 0.413 @ 28155.2
# exch_timestamp: 1680652815029000.0 buy 0.002 @ 28155.2
# exch_timestamp: 1680652815029000.0 buy 0.004 @ 28155.3
# exch_timestamp: 1680652815029000.0 buy 0.001 @ 28155.3
# exch_timestamp: 1680652815029000.0 buy 0.001 @ 28155.3
# exch_timestamp: 1680652815045000.0 sell 0.326 @ 28155.3
# exch_timestamp: 1680652815059000.0 buy 0.02 @ 28155.4
# exch_timestamp: 1680652815059000.0 buy 0.002 @ 28155.4
# exch_timestamp: 1680652815063000.0 buy 0.018 @ 28155.4
# exch_timestamp: 1680652815075000.0 buy 0.001 @ 28155.4
# exch_timestamp: 1680652815081000.0 buy 0.12 @ 28155.4
# exch_timestamp: 1680652815081000.0 buy 0.007 @ 28155.4
# exch_timestamp: 1680652815081000.0 buy 0.001 @ 28155.5
# exch_timestamp: 1680652815081000.0 buy 0.001 @ 28155.5
# exch_timestamp: 1680652815081000.0 buy 0.018 @ 28155.7
# exch_timestamp: 1680652815110000.0 buy 0.001 @ 28155.8
# exch_timestamp: 1680652815110000.0 buy 0.003 @ 28155.8
# exch_timestamp: 1680652815132000.0 buy 0.017 @ 28155.8
# exch_timestamp: 1680652815138000.0 buy 0.001 @ 28156.0
# exch_timestamp: 1680652815138000.0 buy 0.01 @ 28156.0
# exch_timestamp: 1680652815147000.0 buy 0.06 @ 28156.0
# exch_timestamp: 1680652815147000.0 buy 0.008 @ 28156.1
# exch_timestamp: 1680652815147000.0 buy 0.001 @ 28156.5
# exch_timestamp: 1680652815147000.0 buy 0.022 @ 28156.6
# exch_timestamp: 1680652815147000.0 buy 0.052 @ 28156.9
# exch_timestamp: 1680652815147000.0 buy 0.001 @ 28157.0
# exch_timestamp: 1680652815147000.0 buy 0.012 @ 28157.0
# exch_timestamp: 1680652815147000.0 buy 0.035 @ 28157.0
# exch_timestamp: 1680652815147000.0 buy 0.1 @ 28157.1
# exch_timestamp: 1680652815147000.0 buy 0.006 @ 28157.1
# exch_timestamp: 1680652815147000.0 buy 0.064 @ 28157.1
# exch_timestamp: 1680652815147000.0 buy 0.009 @ 28157.1
# exch_timestamp: 1680652815147000.0 buy 0.001 @ 28157.1
# exch_timestamp: 1680652815147000.0 buy 0.014 @ 28157.1
# exch_timestamp: 1680652815147000.0 buy 0.014 @ 28157.1
# exch_timestamp: 1680652815147000.0 buy 0.009 @ 28157.1
# exch_timestamp: 1680652815147000.0 buy 0.357 @ 28157.1
# exch_timestamp: 1680652815147000.0 buy 0.001 @ 28157.1
# exch_timestamp: 1680652815147000.0 buy 0.001 @ 28157.2
# exch_timestamp: 1680652815147000.0 buy 0.054 @ 28157.3
# exch_timestamp: 1680652815147000.0 buy 0.001 @ 28157.3
# exch_timestamp: 1680652815147000.0 buy 0.001 @ 28157.3
# exch_timestamp: 1680652815147000.0 buy 0.001 @ 28157.4
# exch_timestamp: 1680652815147000.0 buy 0.001 @ 28157.4
# exch_timestamp: 1680652815147000.0 buy 0.001 @ 28157.4
# exch_timestamp: 1680652815147000.0 buy 0.001 @ 28157.4
# exch_timestamp: 1680652815147000.0 buy 0.004 @ 28157.4
# exch_timestamp: 1680652815147000.0 buy 0.001 @ 28157.5
# exch_timestamp: 1680652815147000.0 buy 0.001 @ 28157.5
# exch_timestamp: 1680652815147000.0 buy 0.001 @ 28157.5
# exch_timestamp: 1680652815147000.0 buy 0.184 @ 28157.5
# exch_timestamp: 1680652815155000.0 buy 0.316 @ 28157.5
# exch_timestamp: 1680652815155000.0 buy 0.358 @ 28157.5
# exch_timestamp: 1680652815155000.0 buy 0.033 @ 28157.7
# exch_timestamp: 1680652815155000.0 buy 0.001 @ 28157.7
# exch_timestamp: 1680652815155000.0 buy 0.001 @ 28157.7
# exch_timestamp: 1680652815155000.0 buy 0.008 @ 28157.7
# exch_timestamp: 1680652815155000.0 buy 0.348 @ 28157.7
# exch_timestamp: 1680652815194000.0 buy 0.008 @ 28157.7
# exch_timestamp: 1680652815194000.0 buy 0.002 @ 28157.7
# exch_timestamp: 1680652815194000.0 buy 0.002 @ 28157.7
# exch_timestamp: 1680652815194000.0 buy 0.001 @ 28157.8
# exch_timestamp: 1680652815194000.0 buy 0.001 @ 28157.8
# exch_timestamp: 1680652815194000.0 buy 0.001 @ 28157.9
# exch_timestamp: 1680652815194000.0 buy 0.003 @ 28157.9
# exch_timestamp: 1680652815194000.0 buy 0.001 @ 28157.9
# exch_timestamp: 1680652815194000.0 buy 0.001 @ 28157.9
# exch_timestamp: 1680652815194000.0 buy 0.001 @ 28158.0
# exch_timestamp: 1680652815194000.0 buy 0.001 @ 28158.0
# exch_timestamp: 1680652815194000.0 buy 0.055 @ 28158.0
# exch_timestamp: 1680652815194000.0 buy 0.027 @ 28158.0
# exch_timestamp: 1680652815194000.0 buy 0.088 @ 28158.0
# exch_timestamp: 1680652815194000.0 buy 0.001 @ 28158.0
# exch_timestamp: 1680652815194000.0 buy 0.001 @ 28158.0
# exch_timestamp: 1680652815194000.0 buy 0.001 @ 28158.0
# exch_timestamp: 1680652815194000.0 buy 0.335 @ 28158.0
# exch_timestamp: 1680652815194000.0 buy 0.001 @ 28158.2
# exch_timestamp: 1680652815195000.0 buy 0.001 @ 28158.2
# exch_timestamp: 1680652815195000.0 buy 0.07 @ 28158.2
# exch_timestamp: 1680652815195000.0 buy 0.01 @ 28158.3
# exch_timestamp: 1680652815195000.0 buy 0.001 @ 28158.3
# exch_timestamp: 1680652815195000.0 buy 0.054 @ 28158.4
# exch_timestamp: 1680652815195000.0 buy 0.001 @ 28158.4
# exch_timestamp: 1680652815195000.0 buy 0.323 @ 28158.4
# exch_timestamp: 1680652815202000.0 sell 0.262 @ 28158.3
# exch_timestamp: 1680652815223000.0 buy 0.001 @ 28158.5
# exch_timestamp: 1680652815223000.0 buy 0.001 @ 28158.5
# exch_timestamp: 1680652815223000.0 buy 0.001 @ 28158.5
# exch_timestamp: 1680652815223000.0 buy 0.032 @ 28158.6
# exch_timestamp: 1680652815226000.0 buy 0.001 @ 28158.6
# exch_timestamp: 1680652815306000.0 sell 0.002 @ 28158.5
# exch_timestamp: 1680652815312000.0 buy 0.001 @ 28158.6
# exch_timestamp: 1680652815343000.0 buy 0.022 @ 28158.6
# exch_timestamp: 1680652815343000.0 buy 0.001 @ 28158.6
# exch_timestamp: 1680652815344000.0 buy 0.001 @ 28158.6
# exch_timestamp: 1680652815355000.0 buy 0.001 @ 28158.6
# exch_timestamp: 1680652815355000.0 buy 0.001 @ 28158.6
# exch_timestamp: 1680652815355000.0 buy 0.002 @ 28158.6
# exch_timestamp: 1680652815355000.0 buy 0.001 @ 28158.7
# exch_timestamp: 1680652815355000.0 buy 0.001 @ 28159.0
# exch_timestamp: 1680652815355000.0 buy 0.001 @ 28159.0
# exch_timestamp: 1680652815372000.0 sell 0.201 @ 28159.1
# exch_timestamp: 1680652815372000.0 sell 0.212 @ 28159.1
# exch_timestamp: 1680652815372000.0 sell 0.183 @ 28159.1
# exch_timestamp: 1680652815372000.0 sell 0.16 @ 28159.1
# exch_timestamp: 1680652815394000.0 sell 0.124 @ 28159.1
# exch_timestamp: 1680652815394000.0 sell 0.248 @ 28159.1
# exch_timestamp: 1680652815394000.0 sell 0.02 @ 28159.1
# exch_timestamp: 1680652815394000.0 sell 0.043 @ 28159.1
# exch_timestamp: 1680652815394000.0 sell 0.043 @ 28159.1
# exch_timestamp: 1680652815394000.0 sell 0.099 @ 28159.1
# exch_timestamp: 1680652815394000.0 sell 0.099 @ 28159.1
# exch_timestamp: 1680652815394000.0 sell 0.008 @ 28159.1
# exch_timestamp: 1680652815394000.0 sell 0.024 @ 28159.1
# exch_timestamp: 1680652815402000.0 sell 0.075 @ 28159.1
# exch_timestamp: 1680652815402000.0 sell 0.01 @ 28159.1
# exch_timestamp: 1680652815407000.0 sell 0.001 @ 28159.1
# exch_timestamp: 1680652815488000.0 sell 0.789 @ 28159.1
# exch_timestamp: 1680652815488000.0 sell 0.212 @ 28159.1
# exch_timestamp: 1680652815488000.0 sell 0.212 @ 28159.1
# exch_timestamp: 1680652815488000.0 sell 0.212 @ 28159.1
# exch_timestamp: 1680652815488000.0 sell 0.001 @ 28159.1
# exch_timestamp: 1680652815488000.0 sell 0.039 @ 28159.1
# exch_timestamp: 1680652815532000.0 sell 0.08 @ 28159.1
# exch_timestamp: 1680652815692000.0 sell 0.056 @ 28159.1
# exch_timestamp: 1680652815748000.0 sell 0.003 @ 28159.1
# exch_timestamp: 1680652815784000.0 sell 0.941 @ 28159.1
# exch_timestamp: 1680652815784000.0 sell 0.02 @ 28159.1
# exch_timestamp: 1680652815784000.0 sell 0.02 @ 28159.1
# exch_timestamp: 1680652815784000.0 sell 0.356 @ 28159.1
# exch_timestamp: 1680652815784000.0 sell 0.004 @ 28159.1
# exch_timestamp: 1680652815784000.0 sell 0.106 @ 28159.1
# exch_timestamp: 1680652815785000.0 sell 0.065 @ 28159.1
# exch_timestamp: 1680652815785000.0 sell 0.001 @ 28159.1
# exch_timestamp: 1680652815785000.0 sell 0.001 @ 28159.1
# exch_timestamp: 1680652815785000.0 sell 0.002 @ 28159.1
# exch_timestamp: 1680652815785000.0 sell 0.002 @ 28159.1
# exch_timestamp: 1680652815785000.0 sell 0.006 @ 28159.0
# exch_timestamp: 1680652815785000.0 sell 0.02 @ 28158.9
# exch_timestamp: 1680652815785000.0 sell 0.004 @ 28158.9
# exch_timestamp: 1680652815786000.0 sell 0.004 @ 28158.9
# exch_timestamp: 1680652815786000.0 sell 0.02 @ 28158.8
# exch_timestamp: 1680652815786000.0 sell 0.004 @ 28158.8
# exch_timestamp: 1680652815786000.0 sell 0.004 @ 28158.7
# exch_timestamp: 1680652815786000.0 sell 0.001 @ 28158.6
# exch_timestamp: 1680652815786000.0 sell 0.01 @ 28158.5
# exch_timestamp: 1680652815786000.0 sell 0.011 @ 28158.5
# exch_timestamp: 1680652815786000.0 sell 1.037 @ 28158.5
# exch_timestamp: 1680652815796000.0 sell 0.026 @ 28158.5
# exch_timestamp: 1680652815796000.0 sell 0.001 @ 28158.5
# exch_timestamp: 1680652815796000.0 sell 0.001 @ 28158.5
# exch_timestamp: 1680652815818000.0 sell 0.002 @ 28158.4
# exch_timestamp: 1680652815818000.0 sell 0.043 @ 28158.4
# exch_timestamp: 1680652815818000.0 sell 0.007 @ 28158.2
# exch_timestamp: 1680652815833000.0 sell 0.001 @ 28158.1
# exch_timestamp: 1680652815833000.0 sell 0.007 @ 28157.9
# exch_timestamp: 1680652815833000.0 sell 0.007 @ 28157.8
# exch_timestamp: 1680652815833000.0 sell 0.007 @ 28157.7
# exch_timestamp: 1680652815833000.0 sell 0.008 @ 28157.7
# exch_timestamp: 1680652815834000.0 sell 0.006 @ 28157.6
# exch_timestamp: 1680652815834000.0 sell 0.001 @ 28157.6
# exch_timestamp: 1680652815834000.0 sell 0.006 @ 28157.5
# exch_timestamp: 1680652815834000.0 sell 0.142 @ 28157.4
# exch_timestamp: 1680652815834000.0 sell 0.001 @ 28157.4
# exch_timestamp: 1680652815834000.0 sell 0.012 @ 28157.3
# exch_timestamp: 1680652815853000.0 sell 0.001 @ 28157.1
# exch_timestamp: 1680652815874000.0 sell 0.02 @ 28157.1
# exch_timestamp: 1680652815874000.0 sell 0.138 @ 28157.1
# exch_timestamp: 1680652815874000.0 sell 0.001 @ 28157.1
# exch_timestamp: 1680652815874000.0 sell 0.01 @ 28157.1
# exch_timestamp: 1680652815895000.0 sell 0.024 @ 28156.7
# exch_timestamp: 1680652815945000.0 sell 0.005 @ 28156.7
# exch_timestamp: 1680652816006000.0 sell 0.001 @ 28156.7
# exch_timestamp: 1680652816015000.0 sell 0.001 @ 28156.7
# exch_timestamp: 1680652816016000.0 buy 0.007 @ 28156.8
# exch_timestamp: 1680652816130000.0 sell 0.037 @ 28156.7
# exch_timestamp: 1680652816130000.0 sell 0.001 @ 28156.7
# exch_timestamp: 1680652816130000.0 sell 0.02 @ 28156.7
# exch_timestamp: 1680652816130000.0 sell 0.001 @ 28156.7
# exch_timestamp: 1680652816130000.0 sell 0.441 @ 28156.7
# exch_timestamp: 1680652816189000.0 buy 0.001 @ 28156.8
# exch_timestamp: 1680652816192000.0 buy 0.002 @ 28156.8
# exch_timestamp: 1680652816248000.0 buy 0.113 @ 28156.8
# exch_timestamp: 1680652816377000.0 sell 0.646 @ 28156.7
# exch_timestamp: 1680652816377000.0 sell 0.001 @ 28156.7
# exch_timestamp: 1680652816377000.0 sell 0.02 @ 28156.7
# exch_timestamp: 1680652816377000.0 sell 0.502 @ 28156.7
# exch_timestamp: 1680652816396000.0 sell 0.001 @ 28156.7
# exch_timestamp: 1680652816396000.0 sell 0.001 @ 28156.7
# exch_timestamp: 1680652816547000.0 sell 0.001 @ 28156.6
# exch_timestamp: 1680652816547000.0 sell 0.003 @ 28156.6
# exch_timestamp: 1680652816555000.0 sell 0.042 @ 28156.6
# exch_timestamp: 1680652816555000.0 sell 0.004 @ 28156.6
# exch_timestamp: 1680652816555000.0 sell 0.001 @ 28156.6
# exch_timestamp: 1680652816555000.0 sell 0.02 @ 28156.6
# exch_timestamp: 1680652816555000.0 sell 0.02 @ 28156.6
# exch_timestamp: 1680652816585000.0 sell 0.008 @ 28156.5
# exch_timestamp: 1680652816585000.0 sell 0.001 @ 28156.5
# exch_timestamp: 1680652816591000.0 buy 0.031 @ 28156.2
# exch_timestamp: 1680652816638000.0 buy 0.027 @ 28156.2
# exch_timestamp: 1680652816652000.0 sell 0.001 @ 28156.1
# exch_timestamp: 1680652816652000.0 sell 0.001 @ 28156.1
# exch_timestamp: 1680652816652000.0 sell 0.02 @ 28156.1
# exch_timestamp: 1680652816652000.0 sell 0.24 @ 28156.1
# exch_timestamp: 1680652816811000.0 buy 0.001 @ 28156.2
# exch_timestamp: 1680652816813000.0 buy 0.01 @ 28156.2
# exch_timestamp: 1680652816829000.0 buy 0.002 @ 28156.2
# exch_timestamp: 1680652816902000.0 sell 0.071 @ 28156.1
# exch_timestamp: 1680652816902000.0 sell 0.009 @ 28156.1
# exch_timestamp: 1680652816916000.0 sell 0.001 @ 28156.1
# exch_timestamp: 1680652817019000.0 buy 0.008 @ 28156.2
# exch_timestamp: 1680652817203000.0 buy 0.1 @ 28156.2
# exch_timestamp: 1680652817319000.0 sell 0.01 @ 28156.1
# exch_timestamp: 1680652817319000.0 sell 0.147 @ 28156.1
# exch_timestamp: 1680652817352000.0 buy 0.015 @ 28156.2
# exch_timestamp: 1680652817353000.0 buy 0.001 @ 28156.2
# exch_timestamp: 1680652817467000.0 buy 0.008 @ 28156.2
# exch_timestamp: 1680652817560000.0 buy 0.004 @ 28156.2
# exch_timestamp: 1680652817568000.0 buy 0.027 @ 28156.2
# exch_timestamp: 1680652817589000.0 buy 0.007 @ 28156.2
# exch_timestamp: 1680652817616000.0 sell 0.104 @ 28156.1
# exch_timestamp: 1680652817742000.0 sell 0.009 @ 28156.1
# exch_timestamp: 1680652817755000.0 buy 0.004 @ 28156.2
# exch_timestamp: 1680652817776000.0 buy 0.001 @ 28156.2
# exch_timestamp: 1680652817827000.0 buy 0.001 @ 28156.2
# exch_timestamp: 1680652817880000.0 buy 0.03 @ 28156.2
# exch_timestamp: 1680652817939000.0 sell 0.753 @ 28156.1
# exch_timestamp: 1680652817939000.0 sell 0.001 @ 28156.1
# exch_timestamp: 1680652817939000.0 sell 0.02 @ 28156.1
# exch_timestamp: 1680652817939000.0 sell 0.012 @ 28156.1
# exch_timestamp: 1680652817940000.0 sell 0.002 @ 28156.1
# exch_timestamp: 1680652817940000.0 sell 0.02 @ 28156.1
# exch_timestamp: 1680652817940000.0 sell 0.601 @ 28156.1
# exch_timestamp: 1680652818030000.0 buy 0.009 @ 28156.2
# exch_timestamp: 1680652818041000.0 buy 0.015 @ 28156.2
# exch_timestamp: 1680652818127000.0 buy 0.002 @ 28156.2
# exch_timestamp: 1680652818166000.0 sell 0.06 @ 28156.1
# exch_timestamp: 1680652818193000.0 buy 0.088 @ 28156.2
# exch_timestamp: 1680652818221000.0 buy 0.002 @ 28156.2
# exch_timestamp: 1680652818238000.0 sell 0.008 @ 28156.1
# exch_timestamp: 1680652818332000.0 buy 0.001 @ 28156.2
# exch_timestamp: 1680652818351000.0 sell 1.018 @ 28156.1
# exch_timestamp: 1680652818351000.0 sell 0.007 @ 28156.1
# exch_timestamp: 1680652818351000.0 sell 0.032 @ 28156.1
# exch_timestamp: 1680652818351000.0 sell 0.001 @ 28156.1
# exch_timestamp: 1680652818351000.0 sell 0.001 @ 28156.1
# exch_timestamp: 1680652818351000.0 sell 0.02 @ 28156.1
# exch_timestamp: 1680652818351000.0 sell 0.02 @ 28156.1
# exch_timestamp: 1680652818351000.0 sell 0.7 @ 28156.1
# exch_timestamp: 1680652818351000.0 sell 0.219 @ 28156.1
# exch_timestamp: 1680652818351000.0 sell 0.002 @ 28156.1
# exch_timestamp: 1680652818351000.0 sell 0.001 @ 28156.1
# exch_timestamp: 1680652818352000.0 sell 0.812 @ 28156.0
# exch_timestamp: 1680652818352000.0 sell 0.012 @ 28155.9
# exch_timestamp: 1680652818352000.0 sell 0.001 @ 28155.8
# exch_timestamp: 1680652818352000.0 sell 0.004 @ 28155.8
# exch_timestamp: 1680652818352000.0 sell 0.013 @ 28155.8
# exch_timestamp: 1680652818352000.0 sell 0.002 @ 28155.7
# exch_timestamp: 1680652818352000.0 sell 0.001 @ 28155.6
# exch_timestamp: 1680652818352000.0 sell 0.002 @ 28155.5
# exch_timestamp: 1680652818352000.0 sell 0.001 @ 28155.5
# exch_timestamp: 1680652818352000.0 sell 0.001 @ 28155.4
# exch_timestamp: 1680652818352000.0 sell 0.011 @ 28155.4
# exch_timestamp: 1680652818352000.0 sell 0.485 @ 28155.4
# exch_timestamp: 1680652818352000.0 sell 0.089 @ 28155.4
# exch_timestamp: 1680652818352000.0 sell 0.001 @ 28155.3
# exch_timestamp: 1680652818352000.0 sell 0.002 @ 28155.2
# ...
# exch_timestamp: 1680653149058000.0 buy 0.039 @ 28140.0
# exch_timestamp: 1680653149058000.0 buy 0.001 @ 28140.0
# exch_timestamp: 1680653149058000.0 buy 0.039 @ 28140.0
# exch_timestamp: 1680653149058000.0 buy 0.039 @ 28140.0
# exch_timestamp: 1680653149058000.0 buy 0.039 @ 28140.0
# exch_timestamp: 1680653149058000.0 buy 0.039 @ 28140.0
# exch_timestamp: 1680653149058000.0 buy 0.039 @ 28140.0
# exch_timestamp: 1680653149058000.0 buy 0.039 @ 28140.0
# exch_timestamp: 1680653149058000.0 buy 0.007 @ 28140.1
# exch_timestamp: 1680653149058000.0 buy 0.013 @ 28140.1
# exch_timestamp: 1680653149058000.0 buy 0.053 @ 28140.1
# exch_timestamp: 1680653149058000.0 buy 0.17 @ 28140.1
# exch_timestamp: 1680653149058000.0 buy 0.004 @ 28140.2
# exch_timestamp: 1680653149058000.0 buy 0.101 @ 28140.3
# exch_timestamp: 1680653149058000.0 buy 0.256 @ 28140.3
# exch_timestamp: 1680653149058000.0 buy 0.753 @ 28140.3
# exch_timestamp: 1680653149058000.0 buy 0.001 @ 28140.4
# exch_timestamp: 1680653149058000.0 buy 0.009 @ 28140.4
# exch_timestamp: 1680653149058000.0 buy 0.26 @ 28140.5
# exch_timestamp: 1680653149058000.0 buy 0.052 @ 28140.5
# exch_timestamp: 1680653149058000.0 buy 0.001 @ 28140.5
# exch_timestamp: 1680653149058000.0 buy 0.001 @ 28140.5
# exch_timestamp: 1680653149058000.0 buy 0.029 @ 28140.5
# exch_timestamp: 1680653149058000.0 buy 0.001 @ 28140.6
# exch_timestamp: 1680653149058000.0 buy 0.006 @ 28140.6
# exch_timestamp: 1680653149058000.0 buy 0.014 @ 28140.6
# exch_timestamp: 1680653149075000.0 buy 0.007 @ 28140.7
# exch_timestamp: 1680653149075000.0 buy 0.013 @ 28140.7
# exch_timestamp: 1680653149075000.0 buy 0.001 @ 28140.7
# exch_timestamp: 1680653149075000.0 buy 0.001 @ 28140.8
# exch_timestamp: 1680653149075000.0 buy 0.007 @ 28140.8
# exch_timestamp: 1680653149075000.0 buy 0.007 @ 28140.8
# exch_timestamp: 1680653149075000.0 buy 0.025 @ 28140.8
# exch_timestamp: 1680653149075000.0 buy 0.007 @ 28140.9
# exch_timestamp: 1680653149075000.0 buy 0.026 @ 28140.9
# exch_timestamp: 1680653149075000.0 buy 0.001 @ 28141.0
# exch_timestamp: 1680653149075000.0 buy 0.007 @ 28141.0
# exch_timestamp: 1680653149075000.0 buy 0.013 @ 28141.0
# exch_timestamp: 1680653149075000.0 buy 0.02 @ 28141.1
# exch_timestamp: 1680653149075000.0 buy 0.001 @ 28141.1
# exch_timestamp: 1680653149075000.0 buy 0.007 @ 28141.1
# exch_timestamp: 1680653149075000.0 buy 0.004 @ 28141.1
# exch_timestamp: 1680653149075000.0 buy 0.005 @ 28141.1
# exch_timestamp: 1680653149075000.0 buy 0.009 @ 28141.2
# exch_timestamp: 1680653149075000.0 buy 0.007 @ 28141.2
# exch_timestamp: 1680653149075000.0 buy 0.007 @ 28141.2
# exch_timestamp: 1680653149075000.0 buy 0.008 @ 28141.3
# exch_timestamp: 1680653149075000.0 buy 0.009 @ 28141.3
# exch_timestamp: 1680653149075000.0 buy 0.001 @ 28141.4
# exch_timestamp: 1680653149075000.0 buy 0.014 @ 28141.4
# exch_timestamp: 1680653149075000.0 buy 0.007 @ 28141.4
# exch_timestamp: 1680653149075000.0 buy 0.001 @ 28141.5
# exch_timestamp: 1680653149075000.0 buy 0.007 @ 28141.5
# exch_timestamp: 1680653149075000.0 buy 0.008 @ 28141.5
# exch_timestamp: 1680653149075000.0 buy 0.002 @ 28141.6
# exch_timestamp: 1680653149075000.0 buy 0.007 @ 28141.6
# exch_timestamp: 1680653149075000.0 buy 0.004 @ 28141.6
# exch_timestamp: 1680653149075000.0 buy 0.008 @ 28141.6
# exch_timestamp: 1680653149075000.0 buy 0.002 @ 28141.6
# exch_timestamp: 1680653149075000.0 buy 0.002 @ 28141.7
# exch_timestamp: 1680653149075000.0 buy 0.096 @ 28141.7
# exch_timestamp: 1680653149075000.0 buy 0.034 @ 28141.7
# exch_timestamp: 1680653149075000.0 buy 0.089 @ 28141.7
# exch_timestamp: 1680653149075000.0 buy 0.008 @ 28141.7
# exch_timestamp: 1680653149075000.0 buy 0.023 @ 28141.7
# exch_timestamp: 1680653149075000.0 buy 0.002 @ 28141.8
# exch_timestamp: 1680653149075000.0 buy 0.026 @ 28141.8
# exch_timestamp: 1680653149075000.0 buy 0.109 @ 28141.8
# exch_timestamp: 1680653149089000.0 buy 0.001 @ 28141.8
# exch_timestamp: 1680653149122000.0 buy 0.067 @ 28141.8
# exch_timestamp: 1680653149122000.0 buy 0.177 @ 28141.8
# exch_timestamp: 1680653149122000.0 buy 0.001 @ 28141.8
# exch_timestamp: 1680653149122000.0 buy 0.001 @ 28141.8
# exch_timestamp: 1680653149123000.0 buy 0.008 @ 28141.8
# exch_timestamp: 1680653149123000.0 buy 0.001 @ 28141.8
# exch_timestamp: 1680653149123000.0 buy 0.007 @ 28141.8
# exch_timestamp: 1680653149123000.0 buy 0.001 @ 28141.8
# exch_timestamp: 1680653149123000.0 buy 0.001 @ 28141.8
# exch_timestamp: 1680653149123000.0 buy 0.039 @ 28141.8
# exch_timestamp: 1680653149123000.0 buy 0.039 @ 28141.8
# exch_timestamp: 1680653149123000.0 buy 0.039 @ 28141.8
# exch_timestamp: 1680653149123000.0 buy 0.039 @ 28141.8
# exch_timestamp: 1680653149123000.0 buy 0.004 @ 28141.8
# exch_timestamp: 1680653149123000.0 buy 0.039 @ 28141.8
# exch_timestamp: 1680653149123000.0 buy 0.043 @ 28141.8
# exch_timestamp: 1680653149123000.0 buy 0.386 @ 28141.8
# exch_timestamp: 1680653149153000.0 buy 0.011 @ 28141.8
# exch_timestamp: 1680653149197000.0 buy 0.001 @ 28141.8
# exch_timestamp: 1680653149217000.0 sell 0.005 @ 28141.7
# exch_timestamp: 1680653149217000.0 sell 0.006 @ 28141.7
# exch_timestamp: 1680653149575000.0 sell 0.002 @ 28141.7
# exch_timestamp: 1680653149683000.0 buy 0.934 @ 28141.8
# exch_timestamp: 1680653149683000.0 buy 0.02 @ 28141.8
# exch_timestamp: 1680653149683000.0 buy 0.001 @ 28141.8
# exch_timestamp: 1680653149683000.0 buy 0.001 @ 28141.8
# exch_timestamp: 1680653149683000.0 buy 0.167 @ 28141.8
# exch_timestamp: 1680653149683000.0 buy 1.21 @ 28141.8
# exch_timestamp: 1680653149683000.0 buy 0.002 @ 28141.8
# exch_timestamp: 1680653149683000.0 buy 0.884 @ 28141.8
# exch_timestamp: 1680653149691000.0 buy 0.116 @ 28141.8
# exch_timestamp: 1680653149691000.0 buy 0.007 @ 28141.8
# exch_timestamp: 1680653149691000.0 buy 0.016 @ 28141.8
# exch_timestamp: 1680653149691000.0 buy 0.001 @ 28141.8
# exch_timestamp: 1680653149691000.0 buy 0.051 @ 28141.8
# exch_timestamp: 1680653149691000.0 buy 0.001 @ 28141.8
# exch_timestamp: 1680653149691000.0 buy 0.002 @ 28141.8
# exch_timestamp: 1680653149896000.0 sell 0.064 @ 28141.8
# exch_timestamp: 1680653149896000.0 sell 0.596 @ 28141.8
# exch_timestamp: 1680653149896000.0 sell 0.212 @ 28141.8
# exch_timestamp: 1680653149896000.0 sell 0.015 @ 28141.8
# exch_timestamp: 1680653149896000.0 sell 0.008 @ 28141.8
# exch_timestamp: 1680653149896000.0 sell 0.024 @ 28141.8
# exch_timestamp: 1680653149896000.0 sell 0.201 @ 28141.8
# exch_timestamp: 1680653149896000.0 sell 0.04 @ 28141.8
# exch_timestamp: 1680653150051000.0 sell 0.001 @ 28141.8
# exch_timestamp: 1680653150335000.0 buy 0.008 @ 28141.9
# exch_timestamp: 1680653150335000.0 buy 0.02 @ 28141.9
# exch_timestamp: 1680653150335000.0 buy 0.001 @ 28141.9
# exch_timestamp: 1680653150335000.0 buy 0.001 @ 28141.9
# exch_timestamp: 1680653150335000.0 buy 0.05 @ 28141.9
# exch_timestamp: 1680653150507000.0 buy 0.02 @ 28141.9
# exch_timestamp: 1680653150507000.0 buy 0.18 @ 28141.9
# exch_timestamp: 1680653150510000.0 buy 0.006 @ 28141.9
# exch_timestamp: 1680653150510000.0 buy 0.066 @ 28141.9
# exch_timestamp: 1680653150510000.0 buy 0.004 @ 28141.9
# exch_timestamp: 1680653150510000.0 buy 0.013 @ 28141.9
# exch_timestamp: 1680653150510000.0 buy 0.003 @ 28141.9
# exch_timestamp: 1680653150510000.0 buy 0.02 @ 28141.9
# exch_timestamp: 1680653150510000.0 buy 0.001 @ 28141.9
# exch_timestamp: 1680653150510000.0 buy 0.006 @ 28141.9
# exch_timestamp: 1680653150539000.0 buy 0.047 @ 28142.0
# exch_timestamp: 1680653150539000.0 buy 0.017 @ 28142.0
# exch_timestamp: 1680653150541000.0 buy 0.148 @ 28142.0
# exch_timestamp: 1680653150541000.0 buy 0.009 @ 28142.0
# exch_timestamp: 1680653150541000.0 buy 0.001 @ 28142.0
# exch_timestamp: 1680653150541000.0 buy 0.31 @ 28142.0
# exch_timestamp: 1680653150541000.0 buy 0.174 @ 28142.0
# exch_timestamp: 1680653150661000.0 sell 0.011 @ 28141.9
# exch_timestamp: 1680653150764000.0 buy 0.008 @ 28142.0
# exch_timestamp: 1680653150764000.0 buy 0.001 @ 28142.0
# exch_timestamp: 1680653150764000.0 buy 0.003 @ 28142.0
# exch_timestamp: 1680653150764000.0 buy 0.001 @ 28142.0
# exch_timestamp: 1680653150764000.0 buy 0.02 @ 28142.0
# exch_timestamp: 1680653150778000.0 buy 0.02 @ 28142.0
# exch_timestamp: 1680653150778000.0 buy 0.001 @ 28142.0
# exch_timestamp: 1680653150778000.0 buy 0.029 @ 28142.0
# exch_timestamp: 1680653150778000.0 buy 0.001 @ 28142.0
# exch_timestamp: 1680653150778000.0 buy 0.02 @ 28142.0
# exch_timestamp: 1680653150778000.0 buy 0.008 @ 28142.1
# exch_timestamp: 1680653150778000.0 buy 0.02 @ 28142.1
# exch_timestamp: 1680653150789000.0 buy 0.003 @ 28142.2
# exch_timestamp: 1680653150789000.0 buy 0.031 @ 28142.2
# exch_timestamp: 1680653150789000.0 buy 0.001 @ 28142.2
# exch_timestamp: 1680653150789000.0 buy 0.004 @ 28142.3
# exch_timestamp: 1680653150789000.0 buy 0.008 @ 28142.4
# exch_timestamp: 1680653150789000.0 buy 0.616 @ 28142.4
# exch_timestamp: 1680653150790000.0 buy 0.384 @ 28142.4
# exch_timestamp: 1680653150790000.0 buy 0.32 @ 28142.4
# exch_timestamp: 1680653150790000.0 buy 0.64 @ 28142.4
# exch_timestamp: 1680653150790000.0 buy 0.159 @ 28142.4
# exch_timestamp: 1680653150799000.0 buy 0.001 @ 28142.4
# exch_timestamp: 1680653150799000.0 buy 0.001 @ 28142.5
# exch_timestamp: 1680653150799000.0 buy 0.044 @ 28142.5
# exch_timestamp: 1680653150799000.0 buy 0.008 @ 28142.5
# exch_timestamp: 1680653150799000.0 buy 0.017 @ 28142.5
# exch_timestamp: 1680653150799000.0 buy 0.008 @ 28142.6
# exch_timestamp: 1680653150799000.0 buy 0.008 @ 28142.7
# exch_timestamp: 1680653150799000.0 buy 0.008 @ 28142.7
# exch_timestamp: 1680653150799000.0 buy 0.001 @ 28142.8
# exch_timestamp: 1680653150802000.0 buy 0.007 @ 28142.8
# exch_timestamp: 1680653150802000.0 buy 0.008 @ 28142.8
# exch_timestamp: 1680653150802000.0 buy 0.002 @ 28142.9
# exch_timestamp: 1680653150802000.0 buy 0.006 @ 28142.9
# exch_timestamp: 1680653150802000.0 buy 0.003 @ 28142.9
# exch_timestamp: 1680653150802000.0 buy 0.003 @ 28142.9
# exch_timestamp: 1680653150802000.0 buy 0.003 @ 28142.9
# exch_timestamp: 1680653150802000.0 buy 0.001 @ 28142.9
# exch_timestamp: 1680653150802000.0 buy 0.008 @ 28142.9
# exch_timestamp: 1680653150802000.0 buy 0.001 @ 28143.0
# exch_timestamp: 1680653150802000.0 buy 0.001 @ 28143.0
# exch_timestamp: 1680653150802000.0 buy 0.035 @ 28143.0
# exch_timestamp: 1680653150802000.0 buy 0.001 @ 28143.0
# exch_timestamp: 1680653150802000.0 buy 0.008 @ 28143.0
# exch_timestamp: 1680653150805000.0 buy 0.001 @ 28143.5
# exch_timestamp: 1680653150805000.0 buy 0.284 @ 28143.5
# exch_timestamp: 1680653150805000.0 buy 0.151 @ 28143.5
# exch_timestamp: 1680653150805000.0 buy 0.001 @ 28143.6
# exch_timestamp: 1680653150805000.0 buy 0.07 @ 28143.7
# exch_timestamp: 1680653150880000.0 buy 0.001 @ 28143.8
# exch_timestamp: 1680653150880000.0 buy 0.001 @ 28143.8
# exch_timestamp: 1680653150880000.0 buy 0.001 @ 28143.8
# exch_timestamp: 1680653150880000.0 buy 0.02 @ 28143.8
# exch_timestamp: 1680653150880000.0 buy 0.02 @ 28143.8
# exch_timestamp: 1680653150880000.0 buy 0.014 @ 28143.8
# exch_timestamp: 1680653150910000.0 buy 0.626 @ 28143.8
# exch_timestamp: 1680653150910000.0 buy 0.32 @ 28143.8
# exch_timestamp: 1680653150910000.0 buy 0.65 @ 28143.8
# exch_timestamp: 1680653150911000.0 buy 0.023 @ 28143.8
# exch_timestamp: 1680653150918000.0 buy 0.607 @ 28143.8
# exch_timestamp: 1680653150918000.0 buy 0.001 @ 28143.8
# exch_timestamp: 1680653150918000.0 buy 0.163 @ 28143.8
# exch_timestamp: 1680653150936000.0 buy 0.991 @ 28143.8
# exch_timestamp: 1680653150980000.0 buy 0.16 @ 28143.8
# exch_timestamp: 1680653150980000.0 buy 0.02 @ 28143.8
# exch_timestamp: 1680653150980000.0 buy 0.02 @ 28143.8
# exch_timestamp: 1680653150980000.0 buy 0.001 @ 28143.8
# exch_timestamp: 1680653150980000.0 buy 0.04 @ 28143.8
# exch_timestamp: 1680653150980000.0 buy 0.564 @ 28143.8
# exch_timestamp: 1680653151026000.0 buy 0.02 @ 28143.8
# exch_timestamp: 1680653151026000.0 buy 0.64 @ 28143.8
# exch_timestamp: 1680653151026000.0 buy 0.32 @ 28143.8
# exch_timestamp: 1680653151026000.0 buy 0.36 @ 28143.8
# exch_timestamp: 1680653151026000.0 buy 0.16 @ 28143.8
# exch_timestamp: 1680653151026000.0 buy 0.02 @ 28143.8
# exch_timestamp: 1680653151052000.0 buy 0.044 @ 28143.9
# exch_timestamp: 1680653151616000.0 buy 0.028 @ 28143.9
# exch_timestamp: 1680653151773000.0 sell 0.005 @ 28143.8
# exch_timestamp: 1680653151956000.0 sell 0.245 @ 28143.8
# exch_timestamp: 1680653151956000.0 sell 0.212 @ 28143.8
# exch_timestamp: 1680653151956000.0 sell 0.244 @ 28143.8
# exch_timestamp: 1680653152058000.0 sell 0.051 @ 28143.8
# exch_timestamp: 1680653152062000.0 buy 0.16 @ 28143.9
# exch_timestamp: 1680653152062000.0 buy 0.053 @ 28143.9
# exch_timestamp: 1680653152360000.0 buy 0.001 @ 28143.9
# exch_timestamp: 1680653152738000.0 buy 0.001 @ 28143.9
# exch_timestamp: 1680653153179000.0 sell 0.053 @ 28143.8
# exch_timestamp: 1680653153271000.0 sell 0.035 @ 28143.8
# exch_timestamp: 1680653153687000.0 buy 0.01 @ 28143.9
# exch_timestamp: 1680653153687000.0 buy 0.02 @ 28143.9
# exch_timestamp: 1680653153687000.0 buy 0.021 @ 28143.9
# exch_timestamp: 1680653154191000.0 sell 0.004 @ 28143.8
# exch_timestamp: 1680653154279000.0 buy 0.001 @ 28143.9
# exch_timestamp: 1680653154494000.0 buy 0.001 @ 28143.9
# exch_timestamp: 1680653154502000.0 sell 0.072 @ 28143.8
# exch_timestamp: 1680653154577000.0 sell 0.183 @ 28143.8
# exch_timestamp: 1680653154831000.0 sell 0.573 @ 28143.8
# exch_timestamp: 1680653154897000.0 sell 1.287 @ 28143.8
# exch_timestamp: 1680653155327000.0 sell 0.014 @ 28143.8
# exch_timestamp: 1680653155595000.0 sell 0.2 @ 28143.8
# exch_timestamp: 1680653155684000.0 buy 0.001 @ 28143.9
# exch_timestamp: 1680653155684000.0 buy 0.001 @ 28143.9
# exch_timestamp: 1680653155684000.0 buy 0.001 @ 28143.9
# exch_timestamp: 1680653155684000.0 buy 0.001 @ 28143.9
# exch_timestamp: 1680653155684000.0 buy 0.001 @ 28143.9
# exch_timestamp: 1680653155981000.0 sell 0.004 @ 28143.8
# exch_timestamp: 1680653156077000.0 sell 0.041 @ 28143.8
# exch_timestamp: 1680653156099000.0 sell 0.001 @ 28143.8
# exch_timestamp: 1680653156285000.0 buy 0.001 @ 28143.9
# exch_timestamp: 1680653156409000.0 sell 0.17 @ 28143.8
# exch_timestamp: 1680653156485000.0 buy 0.001 @ 28143.9
# exch_timestamp: 1680653156651000.0 buy 0.001 @ 28143.9
# exch_timestamp: 1680653156651000.0 buy 0.001 @ 28143.9
# exch_timestamp: 1680653156651000.0 buy 0.001 @ 28143.9
# exch_timestamp: 1680653156651000.0 buy 0.001 @ 28143.9
# exch_timestamp: 1680653156651000.0 buy 0.001 @ 28143.9
# exch_timestamp: 1680653157297000.0 buy 0.006 @ 28143.9
# exch_timestamp: 1680653157297000.0 buy 0.001 @ 28143.9
# exch_timestamp: 1680653157297000.0 buy 0.001 @ 28143.9
# exch_timestamp: 1680653157297000.0 buy 0.004 @ 28143.9
# exch_timestamp: 1680653157391000.0 buy 0.082 @ 28143.9
# exch_timestamp: 1680653157391000.0 buy 0.001 @ 28143.9
# exch_timestamp: 1680653157391000.0 buy 0.117 @ 28143.9
# exch_timestamp: 1680653158036000.0 buy 0.001 @ 28143.9
# exch_timestamp: 1680653158083000.0 buy 0.066 @ 28143.9
# exch_timestamp: 1680653158205000.0 buy 0.176 @ 28143.9
# exch_timestamp: 1680653158205000.0 buy 0.003 @ 28143.9
# exch_timestamp: 1680653158205000.0 buy 0.001 @ 28143.9
# exch_timestamp: 1680653158205000.0 buy 0.08 @ 28143.9
# exch_timestamp: 1680653158205000.0 buy 0.001 @ 28143.9
# exch_timestamp: 1680653158205000.0 buy 0.007 @ 28143.9
# exch_timestamp: 1680653158205000.0 buy 0.001 @ 28143.9
# exch_timestamp: 1680653158205000.0 buy 0.001 @ 28143.9
# exch_timestamp: 1680653158205000.0 buy 0.001 @ 28143.9
# exch_timestamp: 1680653158205000.0 buy 0.02 @ 28143.9
# exch_timestamp: 1680653158205000.0 buy 0.003 @ 28143.9
# exch_timestamp: 1680653158205000.0 buy 0.001 @ 28143.9
# exch_timestamp: 1680653158205000.0 buy 0.7 @ 28143.9
# exch_timestamp: 1680653158205000.0 buy 0.546 @ 28143.9
# exch_timestamp: 1680653158209000.0 sell 0.047 @ 28143.8
# exch_timestamp: 1680653158209000.0 sell 0.02 @ 28143.8
# exch_timestamp: 1680653158209000.0 sell 0.004 @ 28143.8
# exch_timestamp: 1680653158209000.0 sell 0.02 @ 28143.8
# exch_timestamp: 1680653158209000.0 sell 0.003 @ 28143.8
# exch_timestamp: 1680653158572000.0 buy 0.061 @ 28143.9
# exch_timestamp: 1680653158808000.0 buy 0.001 @ 28143.9
# exch_timestamp: 1680653158827000.0 buy 0.002 @ 28143.9
# exch_timestamp: 1680653158902000.0 sell 0.002 @ 28143.8
# exch_timestamp: 1680653158902000.0 sell 0.05 @ 28143.8
# exch_timestamp: 1680653159317000.0 sell 0.041 @ 28143.8
# exch_timestamp: 1680653159899000.0 sell 1.16 @ 28143.8
# False

# %% [markdown]
# ## Rolling Volume-Weighted Average Price

# %%
@njit
def rolling_vwap(hbt, out):
    trade_idx = np.empty(100_000, np.int64)
    idx = 0
    last_trade_price = np.nan
    
    while hbt.run:
        if not hbt.elapse(10 * 1e6):
            return False
        
        trade_idx[idx] = len(hbt.last_trades)
        
        current = trade_idx[idx]

        sum_buy_price_qty = np.nan
        sum_buy_qty = np.nan
        sum_sell_price_qty = np.nan
        sum_sell_qty = np.nan
        
        if idx >= 6:
            lookback_1min = trade_idx[idx - 6]

            sum_buy_price_qty = 0.0
            sum_buy_qty = 0.0
            sum_sell_price_qty = 0.0
            sum_sell_qty = 0.0
            
            for trade in hbt.last_trades[lookback_1min:current]:
                if trade[COL_SIDE] == 1:
                    sum_buy_price_qty += trade[COL_PRICE] * trade[COL_QTY]
                    sum_buy_qty += trade[COL_QTY]
                else:
                    sum_sell_price_qty += trade[COL_PRICE] * trade[COL_QTY]
                    sum_sell_qty += trade[COL_QTY]

        vwap1m = np.divide(sum_buy_price_qty + sum_sell_price_qty, sum_buy_qty + sum_sell_qty)
        buy_vwap1m = np.divide(sum_buy_price_qty, sum_buy_qty)
        sell_vwap1m = np.divide(sum_sell_price_qty, sum_sell_qty)
                    
        sum_price_qty = np.nan
        sum_qty = np.nan
                    
        if idx >= 1:
            lookback_10sec = trade_idx[idx - 1]
            
            sum_price_qty = 0.0
            sum_qty = 0.0
            
            for trade in hbt.last_trades[lookback_10sec:current]:
                sum_price_qty += trade[COL_PRICE] * trade[COL_QTY]
                sum_qty += trade[COL_QTY]
        
        vwap10sec = np.divide(sum_price_qty, sum_qty)
        
        out.append((hbt.current_timestamp, vwap10sec, vwap1m, buy_vwap1m, sell_vwap1m))
        idx += 1
    return True

# %%
hbt = HftBacktest(
    btcusdt_20230405,
    tick_size=0.1,
    lot_size=0.001,
    maker_fee=0.0002,
    taker_fee=0.0007,
    order_latency=FeedLatency(),
    asset_type=Linear,
    snapshot=btcusdt_20230404_eod,
    trade_list_size=1_000_000
)

tup_ty = Tuple((float64, float64, float64, float64, float64))
out = List.empty_list(tup_ty, allocated=100_000)

rolling_vwap(hbt, out)
# Out:
# False

# %%
df = pl.DataFrame(out).transpose()
df.columns = ['Local Timestamp', '10-sec VWAP', '1-min VWAP', '1-min Buy VWAP', '1-min Sell VWAP']
df = df.with_columns(
    pl.from_epoch('Local Timestamp', time_unit='us')
)

df
# Out:
# shape: (41, 5)
# ┌────────────────────────────┬──────────────┬──────────────┬────────────────┬─────────────────┐
# │ Local Timestamp            ┆ 10-sec VWAP  ┆ 1-min VWAP   ┆ 1-min Buy VWAP ┆ 1-min Sell VWAP │
# │ ---                        ┆ ---          ┆ ---          ┆ ---            ┆ ---             │
# │ datetime[μs]               ┆ f64          ┆ f64          ┆ f64            ┆ f64             │
# ╞════════════════════════════╪══════════════╪══════════════╪════════════════╪═════════════════╡
# │ 2023-04-05 00:00:10.032116 ┆ NaN          ┆ NaN          ┆ NaN            ┆ NaN             │
# │ 2023-04-05 00:00:20.032116 ┆ 28155.780263 ┆ NaN          ┆ NaN            ┆ NaN             │
# │ 2023-04-05 00:00:30.032116 ┆ 28158.015906 ┆ NaN          ┆ NaN            ┆ NaN             │
# │ 2023-04-05 00:00:40.032116 ┆ 28155.813019 ┆ NaN          ┆ NaN            ┆ NaN             │
# │ …                          ┆ …            ┆ …            ┆ …              ┆ …               │
# │ 2023-04-05 00:06:20.032116 ┆ 28138.54843  ┆ 28140.391805 ┆ 28140.716124   ┆ 28140.025369    │
# │ 2023-04-05 00:06:30.032116 ┆ 28137.611515 ┆ 28139.958313 ┆ 28139.962781   ┆ 28139.951255    │
# │ 2023-04-05 00:06:40.032116 ┆ 28140.107487 ┆ 28139.965883 ┆ 28139.964373   ┆ 28139.9681      │
# │ 2023-04-05 00:06:50.032116 ┆ 28139.449719 ┆ 28139.746092 ┆ 28139.841886   ┆ 28139.673659    │
# └────────────────────────────┴──────────────┴──────────────┴────────────────┴─────────────────┘

# %%
plt.plot(df['Local Timestamp'], df['10-sec VWAP'])
plt.plot(df['Local Timestamp'], df['1-min VWAP'])
plt.plot(df['Local Timestamp'], df['1-min Buy VWAP'])
plt.plot(df['Local Timestamp'], df['1-min Sell VWAP'])

plt.legend(['10-sec VWAP', '1-min VWAP', '1-min Buy VWAP', '1-min Sell VWAP'])
